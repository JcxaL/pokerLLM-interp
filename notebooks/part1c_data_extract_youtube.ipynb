# %% [markdown]
# ### Load environment variables

# %%
from dotenv import load_dotenv
import os

# 加载 .env 文件
load_dotenv(override=True)

# 访问环境变量
YOUTUBE_API_KEY = os.getenv('YOUTUBE_API_KEY')
AWS_ACCESS_KEY_ID = os.getenv('AWS_ACCESS_KEY_ID')
AWS_SECRET_ACCESS_KEY = os.getenv('AWS_SECRET_ACCESS_KEY')
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
S3_BUCKET_NAME = os.getenv('S3_BUCKET_NAME')

# %% [markdown]
# ### Youtube API

# %%
from googleapiclient.discovery import build

def search_youtube_videos(query, max_results=50):
    """
    使用 YouTube Data API 搜索视频，支持分页
    :param query: 搜索关键字
    :param max_results: 需要返回的总视频数量
    :return: 视频的标题和完整链接
    """
    youtube = build("youtube", "v3", developerKey=YOUTUBE_API_KEY)
    video_results = []
    next_page_token = None
    
    while len(video_results) < max_results:
        # 计算本次请求需要的结果数
        remaining = min(50, max_results - len(video_results))
        
        # 执行搜索请求
        request = youtube.search().list(
            part="snippet",
            q=query,
            maxResults=remaining,
            type="video",
            pageToken=next_page_token
        )
        response = request.execute()
        
        # 提取视频信息
        for item in response.get('items', []):
            video_id = item['id']['videoId']
            title = item['snippet']['title']
            url = f"https://www.youtube.com/watch?v={video_id}"
            video_results.append({'title': title, 'video_id': video_id, 'url': url})
        
        # 获取下一页的 token
        next_page_token = response.get('nextPageToken')
        
        # 如果没有下一页，就退出循环
        if not next_page_token:
            break
        
        print(f"已获取 {len(video_results)} 个视频...")
    
    print(f"总共获取 {len(video_results)} 个视频")
    return video_results

# %%
query = "No Limit Texas Hold'em poker strategy"

# %%
results = search_youtube_videos(query,10)
results
# Out:
# [{'title': 'This Easy No Limit Hold&#39;em Strategy SKYROCKETED My Winnings',
#   'video_id': 'eAJG5q-_OoU',
#   'url': 'https://www.youtube.com/watch?v=eAJG5q-_OoU'},
#  {'title': 'Win More at Poker - Easy Strategy for Hold&#39;em Starting Hands',
#   'video_id': 'aJ3rfNH-yGY',
#   'url': 'https://www.youtube.com/watch?v=aJ3rfNH-yGY'},
#  {'title': 'How to Play Poker for Beginners | PokerStars Learn',
#   'video_id': 'pSRGErzzIo4',
#   'url': 'https://www.youtube.com/watch?v=pSRGErzzIo4'},
#  {'title': 'How to Play Limit Hold&#39;em',
#   'video_id': '-cu4kQhARJI',
#   'url': 'https://www.youtube.com/watch?v=-cu4kQhARJI'},
#  {'title': 'How to Play No Limit Texas Hold’em (5 Beginner Poker Strategies)',
#   'video_id': 'bcKjZq43NjE',
#   'url': 'https://www.youtube.com/watch?v=bcKjZq43NjE'},
#  {'title': 'TOP 10 Cash Game TIPS! [Master The Fundamentals]',
#   'video_id': 'f-MnvLLYqPE',
#   'url': 'https://www.youtube.com/watch?v=f-MnvLLYqPE'},
#  {'title': '9 TEXAS HOLD&#39;EM Poker Tips For Beginners (Just Do This!)',
#   'video_id': 'noKz7aCfwNM',
#   'url': 'https://www.youtube.com/watch?v=noKz7aCfwNM'},
#  {'title': 'No Limit Texas Hold&#39;em Basics - Everything Poker [Ep. 01] | PokerStars',
#   'video_id': 'ZuK0huIhr3A',
#   'url': 'https://www.youtube.com/watch?v=ZuK0huIhr3A'},
#  {'title': 'Mid-stakes grind on Coin Poker 25nl | 50nl | 100nl | Texas Holdem Poker | NLE | Poker',
#   'video_id': 'EKB-qfS5CfY',
#   'url': 'https://www.youtube.com/watch?v=EKB-qfS5CfY'},
#  {'title': '🎒 📈 How to Play Poker - Texas Hold&#39;em Rules Made Easy',
#   'video_id': 'GAoR9ji8D6A',
#   'url': 'https://www.youtube.com/watch?v=GAoR9ji8D6A'}]

# %%
from youtube_transcript_api import YouTubeTranscriptApi
import json

def get_transcript(video_id):
    """
    使用 youtube-transcript-api 获取视频的转录文本
    :param video_id: YouTube 视频 ID
    :return: 转录文本的 JSON 字符串
    """
    try:
        transcript_list = YouTubeTranscriptApi.get_transcript(video_id)
        # 直接返回 JSON 字符串
        return json.dumps(transcript_list)
    except Exception as e:
        print(f"获取字幕失败: {str(e)}")
        return "[]"  # 如果获取失败，返回空数组的字符串表示

# %%
for video in results:
    transcript = get_transcript(video['video_id'])
    print(transcript)
# Out:
# [{'text': "what's going on guys today I'm going to", 'start': 0.0, 'duration': 4.02}, {'text': 'walk you step by step through the simple', 'start': 1.8, 'duration': 4.62}, {'text': 'poker strategy that will quickly boost', 'start': 4.02, 'duration': 4.26}, {'text': "your winnings let's jump into it all", 'start': 6.42, 'duration': 3.599}, {'text': 'right guys do you play small stakes', 'start': 8.28, 'duration': 5.1}, {'text': "poker if you're like 95 of people you", 'start': 10.019, 'duration': 5.881}, {'text': 'probably do this would be Stakes like a', 'start': 13.38, 'duration': 4.319}, {'text': 'one dollar two dollar cash game at a', 'start': 15.9, 'duration': 4.68}, {'text': 'casino a 20 tournament 50 tournament', 'start': 17.699, 'duration': 5.281}, {'text': 'maybe a 50 buy-in cash game on the', 'start': 20.58, 'duration': 4.5}, {'text': 'internet you guys get the idea these are', 'start': 22.98, 'duration': 3.84}, {'text': 'the stakes that the vast majority of', 'start': 25.08, 'duration': 4.32}, {'text': 'people play in this simple variable bet', 'start': 26.82, 'duration': 4.26}, {'text': "sizing strategy that I'm going to show", 'start': 29.4, 'duration': 4.499}, {'text': 'you today Works unbelievably well', 'start': 31.08, 'duration': 4.74}, {'text': "against the players in this game let's", 'start': 33.899, 'duration': 3.66}, {'text': "give you an example right now so you've", 'start': 35.82, 'duration': 3.84}, {'text': 'got two red Aces Ace of Hearts Ace of', 'start': 37.559, 'duration': 4.081}, {'text': 'Diamonds best hand ever created in No', 'start': 39.66, 'duration': 4.68}, {'text': "Limit Texas Hold'em in the big blind in", 'start': 41.64, 'duration': 4.439}, {'text': 'the aforementioned one dollar two dollar', 'start': 44.34, 'duration': 5.46}, {'text': 'cash Cam and a fish raises it up to six', 'start': 46.079, 'duration': 5.581}, {'text': 'dollars now guys this is absolutely', 'start': 49.8, 'duration': 3.66}, {'text': 'crucial for those of you guys who watch', 'start': 51.66, 'duration': 3.239}, {'text': 'my videos here you know that everything', 'start': 53.46, 'duration': 3.54}, {'text': 'that I discuss in this game always', 'start': 54.899, 'duration': 4.381}, {'text': 'revolves around the player type I play', 'start': 57.0, 'duration': 4.5}, {'text': 'my hand very three differently depending', 'start': 59.28, 'duration': 3.84}, {'text': "on whether I'm up against a recreational", 'start': 61.5, 'duration': 3.299}, {'text': "player fish like we're discussing today", 'start': 63.12, 'duration': 3.84}, {'text': 'a loose and aggressive player a tight', 'start': 64.799, 'duration': 3.661}, {'text': 'passive player I have tons of other', 'start': 66.96, 'duration': 3.42}, {'text': 'videos on how to play against those', 'start': 68.46, 'duration': 3.36}, {'text': "players but today we're talking about", 'start': 70.38, 'duration': 2.76}, {'text': 'our fishy friends these are the players', 'start': 71.82, 'duration': 3.0}, {'text': 'who play any two cards they will chase', 'start': 73.14, 'duration': 3.479}, {'text': 'you down with any pair they will call', 'start': 74.82, 'duration': 3.72}, {'text': "any draw you guys know what I'm talking", 'start': 76.619, 'duration': 3.241}, {'text': 'about these are the players that give', 'start': 78.54, 'duration': 2.939}, {'text': "you the bad beats and so on so let's", 'start': 79.86, 'duration': 3.42}, {'text': 'talk about what to do versus these', 'start': 81.479, 'duration': 3.721}, {'text': 'players well guys what you want to do is', 'start': 83.28, 'duration': 4.019}, {'text': 'you want to over raise versus the', 'start': 85.2, 'duration': 3.48}, {'text': 'wrecked players and when I say Rec', 'start': 87.299, 'duration': 2.941}, {'text': "players in this video I'm talking about", 'start': 88.68, 'duration': 3.6}, {'text': 'the fish these are the recreational', 'start': 90.24, 'duration': 4.44}, {'text': 'players so with pocket aces here guys', 'start': 92.28, ' ...
# [{'text': "making money in no limit texas hold'em", 'start': 3.439, 'duration': 4.001}, {'text': 'starts with the hands you choose to play', 'start': 5.44, 'duration': 4.079}, {'text': 'and how you play them', 'start': 7.44, 'duration': 4.239}, {'text': 'even top 10 starting hands can be the', 'start': 9.519, 'duration': 4.16}, {'text': 'wrong hand to play depending on the', 'start': 11.679, 'duration': 5.0}, {'text': 'situation', 'start': 13.679, 'duration': 3.0}, {'text': '[Music]', 'start': 17.63, 'duration': 3.569}, {'text': 'pocket aces', 'start': 18.72, 'duration': 5.92}, {'text': 'pocket aces show up once every 221 hands', 'start': 21.199, 'duration': 6.0}, {'text': 'so make them count while position can', 'start': 24.64, 'duration': 5.039}, {'text': 'make a difference and trapping can work', 'start': 27.199, 'duration': 4.16}, {'text': 'focus on getting money into the pot', 'start': 29.679, 'duration': 4.241}, {'text': 'early to maximize value', 'start': 31.359, 'duration': 4.72}, {'text': 'aces are the very best starting hand but', 'start': 33.92, 'duration': 3.84}, {'text': "if the board doesn't improve your hand", 'start': 36.079, 'duration': 4.0}, {'text': 'you still only have one pair', 'start': 37.76, 'duration': 4.4}, {'text': 'keep that in mind to avoid stacking off', 'start': 40.079, 'duration': 5.761}, {'text': 'to random two pairs and sets', 'start': 42.16, 'duration': 3.68}, {'text': 'pocket kings', 'start': 46.0, 'duration': 2.879}, {'text': 'pocket kings are almost identical to', 'start': 49.12, 'duration': 4.72}, {'text': "ace's pre-flop some players will fold", 'start': 51.12, 'duration': 5.279}, {'text': "kings but it's rarely correct the odds", 'start': 53.84, 'duration': 4.719}, {'text': 'are 22-1 against someone having a better', 'start': 56.399, 'duration': 4.48}, {'text': 'starting hand at a nine-handed table so', 'start': 58.559, 'duration': 4.0}, {'text': 'try to get as much money into the pot', 'start': 60.879, 'duration': 3.201}, {'text': 'early as you can', 'start': 62.559, 'duration': 3.521}, {'text': "an ace on the flop isn't always a death", 'start': 64.08, 'duration': 3.6}, {'text': "sentence but if you're facing an", 'start': 66.08, 'duration': 3.84}, {'text': 'overcard or a particularly connected', 'start': 67.68, 'duration': 5.2}, {'text': 'board focus on pot control', 'start': 69.92, 'duration': 4.4}, {'text': 'if you have an over pair on an', 'start': 72.88, 'duration': 3.2}, {'text': 'unconnected board you probably have the', 'start': 74.32, 'duration': 3.839}, {'text': 'best hand so focus on getting value from', 'start': 76.08, 'duration': 6.56}, {'text': 'lower over pairs and top pair hands', 'start': 78.159, 'duration': 4.481}, {'text': 'pocket queens and jacks', 'start': 83.2, 'duration': 3.84}, {'text': '[Music]', 'start': 85.18, 'duration': 4.02}, {'text': 'unlike ace ace and king king pocket', 'start': 87.04, 'duration': 4.64}, {'text': 'queens and jacks are foldable pre-flop', 'start': 89.2, 'duration': 4.8}, {'text': "in certain situations if you're at a", 'start': 91.68, 'duration': 4.24}, {'text': 'tight table and people are only racing', 'start': 94.0, 'duration': 4.079}, {'text': 'with legit hands getting involved after', 'start': 95.92, 'duration': 5.36}, {'text': 'a raise and a re-raise can be a mistake', 'start': 98.079, 'duration': 4.961}, {'text': 'with pocket queens at a nine-handed', 'start': 101.28, 'duration': 4.56}, {'text': 'table odds are 10.5 to 1 against someone', 'start': 103.04, 'duration': 4.56}, {'text': 'having a better starting hand than you', 'start': 105.84, 'duration': 3.52}, {'text': 'with pocket jacks the odds go down to', 'start': 107.6, 'duration': 4.96}, {'text': "7-1 there's a 51 chance you'll miss your", 'start': 109.36, 'duration': 5.039}, {'text': 'set and see an overcard on the board', 'start': 112.56, 'duration': 4.4}, {'text': 'when you have pocket jacks and a 38', 'start': 114.399, 'duration': 4.561}, {'text': 'chance with pocket quee ...
# [{'text': 'Hello, welcome to PokerStars Learn.', 'start': 0.3, 'duration': 1.9}, {'text': "I'm James Hartigan and this is\nthe only 'How to Play Poker...", 'start': 2.25, 'duration': 3.39}, {'text': "for Beginners' guide you need to\n start your poker journey.", 'start': 5.74, 'duration': 3.243}, {'text': 'After watching this video,', 'start': 9.033, 'duration': 1.267}, {'text': 'you will know the basics and be\nable to play your first hand of poker.', 'start': 10.4, 'duration': 3.7}, {'text': "And if you want to learn more, please\n don't forget to subscribe to our channel.", 'start': 14.5, 'duration': 3.1}, {'text': 'So, when we talk about poker, the\nmost popular version of the game -', 'start': 20.0, 'duration': 2.8}, {'text': 'which you see in movies, on TV, and\non live streams -', 'start': 22.85, 'duration': 3.197}, {'text': "is No Limit Texas Hold'em,", 'start': 26.097, 'duration': 1.303}, {'text': "and that's what we are going to\nlearn to play in this video.", 'start': 27.4, 'duration': 2.4}, {'text': "The aim of Texas Hold'em is simple:\nmake the best five-card poker hand...", 'start': 30.25, 'duration': 3.85}, {'text': "from the two cards you've been dealt \nand the five shared cards...", 'start': 34.2, 'duration': 3.28}, {'text': 'in the middle of the table.', 'start': 37.58, 'duration': 1.578}, {'text': 'Or act like you have the best\n five-card hand!', 'start': 39.258, 'duration': 2.645}, {'text': "So what beats what? Well, let's run\n through the official hand", 'start': 42.053, 'duration': 2.881}, {'text': 'rankings, starting at the bottom\n and work your way to the top.', 'start': 44.984, 'duration': 3.516}, {'text': 'The worst you can have is a high\ncard. No two cards are the same,', 'start': 48.95, 'duration': 3.503}, {'text': "and the five cards don't connect\n in any other way.", 'start': 52.503, 'duration': 2.497}, {'text': "Ideally, you'd like to have at least\none pair: two cards of the same value.", 'start': 55.65, 'duration': 4.325}, {'text': 'Aces are the highest pair. A pair of twos\n is the lowest.', 'start': 60.075, 'duration': 3.926}, {'text': 'Two pair is better. Pretty self-explanatory.', 'start': 64.675, 'duration': 1.978}, {'text': 'In this example, a pair of Kings \nand a pair of Sixes.', 'start': 66.753, 'duration': 3.748}, {'text': 'Three-of-a-kind is also pretty \nself-explanatory, and it beats two pair.', 'start': 70.651, 'duration': 5.074}, {'text': 'Next up, a straight: Five cards\n in a row of different suits.', 'start': 75.825, 'duration': 4.775}, {'text': 'An ace can be high or low but\nno wraparounds are allowed.', 'start': 80.85, 'duration': 4.464}, {'text': 'Queen-King-Ace-Two-Three\n is not a hand!', 'start': 85.364, 'duration': 3.336}, {'text': "Then a flush: Five cards of the\nsame suit, doesn't matter what...", 'start': 89.4, 'duration': 3.1}, {'text': "order they're in.", 'start': 92.6, 'duration': 1.015}, {'text': "A full house  - also known as a boat -\nIt's where you have three-of-a-kind plus a pair,", 'start': 93.715, 'duration': 4.888}, {'text': "That is a very strong hand, but it's\nstill beaten by quads,", 'start': 98.703, 'duration': 4.148}, {'text': 'officially known as four-of-a-kind.', 'start': 102.901, 'duration': 2.399}, {'text': 'A straight flush is an incredibly\nrare hand.', 'start': 106.35, 'duration': 2.781}, {'text': 'Five cards in a row, all of the \nsame suit.', 'start': 109.231, 'duration': 3.291}, {'text': "And the Royal Flush is unbeatable.\n It's a straight flush - Ten to the Ace.", 'start': 112.572, 'duration': 4.628}, {'text': 'Please note your chances of being\ndealt this hand are roughly 30,000 to 1!', 'start': 117.5, 'duration': 5.1}, {'text': 'And those are the hand rankings.\nTo recap: It goes high card, one pair,', 'start': 122.95, 'duration': 5.765}, {'text': 'two pair, three-of-a-kind,\n a straight, a flush, a full house,', 'start': 128.999, 'duration': 4.701}, {'text': 'four-of-a-kind, straight flush, \nand the Royal Flush.', 'start': 13 ...
# [{'text': 'well hello everybody hope you guys have', 'start': 0.16, 'duration': 3.44}, {'text': 'been enjoying this series learning new', 'start': 1.8, 'duration': 4.4}, {'text': "games having some fun um if you'd like", 'start': 3.6, 'duration': 4.199}, {'text': 'something a little more meaty you can', 'start': 6.2, 'duration': 3.319}, {'text': 'check the uh one of the videos I got', 'start': 7.799, 'duration': 3.88}, {'text': 'down there mix game clinic right a', 'start': 9.519, 'duration': 4.16}, {'text': 'little taste you can watch mix Clin mix', 'start': 11.679, 'duration': 3.681}, {'text': 'game Clinic hand number one or you can', 'start': 13.679, 'duration': 4.001}, {'text': 'watch the entire final table that myself', 'start': 15.36, 'duration': 4.48}, {'text': 'and Jason Somerville broke down uh we', 'start': 17.68, 'duration': 3.96}, {'text': 'went over every hand with a fine tooth', 'start': 19.84, 'duration': 3.84}, {'text': 'comb lots of deep strategy there so', 'start': 21.64, 'duration': 4.04}, {'text': 'hopefully these you know videos here', 'start': 23.68, 'duration': 4.679}, {'text': "inspire you to explore now we're going", 'start': 25.68, 'duration': 5.4}, {'text': 'to take a like blast look at history in', 'start': 28.359, 'duration': 5.04}, {'text': 'a way because when I started playing', 'start': 31.08, 'duration': 4.44}, {'text': 'poker the most popular form of Poker was', 'start': 33.399, 'duration': 4.441}, {'text': 'the following limit hold okay no limit', 'start': 35.52, 'duration': 4.0}, {'text': "holdom wasn't played in cash games it", 'start': 37.84, 'duration': 3.199}, {'text': 'was uh played occasionally in', 'start': 39.52, 'duration': 3.12}, {'text': 'tournaments you know and you play them', 'start': 41.039, 'duration': 3.0}, {'text': 'here and there but even the tournaments', 'start': 42.64, 'duration': 3.48}, {'text': 'were limit holdom when the party poker', 'start': 44.039, 'duration': 3.84}, {'text': 'million many years ago had their thing', 'start': 46.12, 'duration': 3.56}, {'text': 'on the boat it was limit hold them I', 'start': 47.879, 'duration': 2.881}, {'text': 'remember because I got heads up with', 'start': 49.68, 'duration': 3.28}, {'text': 'Eric liner and he beat', 'start': 50.76, 'duration': 4.319}, {'text': 'me I do my own sound effects how you', 'start': 52.96, 'duration': 5.2}, {'text': "like that um so limit hold him well it's", 'start': 55.079, 'duration': 5.12}, {'text': 'a really really fun game I love the game', 'start': 58.16, 'duration': 3.6}, {'text': 'uh a lot of people frown upon it', 'start': 60.199, 'duration': 2.921}, {'text': 'especially No Limit holding players', 'start': 61.76, 'duration': 2.64}, {'text': 'because you know they want to be able to', 'start': 63.12, 'duration': 2.72}, {'text': "Bluff and move all in and that's not", 'start': 64.4, 'duration': 3.48}, {'text': 'what really the game is about okay and', 'start': 65.84, 'duration': 4.04}, {'text': "we'll talk about that a little further", 'start': 67.88, 'duration': 3.32}, {'text': 'first and foremost before we get there', 'start': 69.88, 'duration': 2.52}, {'text': "let's get the nitty-gritty out of the", 'start': 71.2, 'duration': 3.0}, {'text': 'way limit hold them works just like no', 'start': 72.4, 'duration': 3.12}, {'text': "limit hold them except they're", 'start': 74.2, 'duration': 3.16}, {'text': "structured betting right so if you're", 'start': 75.52, 'duration': 4.84}, {'text': 'playing 100 200 the blinds would be 50', 'start': 77.36, 'duration': 6.2}, {'text': '100 the rais is to 200 to 300 to 400 and', 'start': 80.36, 'duration': 4.439}, {'text': "there's a maximum of a bet depending", 'start': 83.56, 'duration': 2.84}, {'text': "which casino you're playing either a bet", 'start': 84.799, 'duration': 3.96}, {'text': 'in three raises or a bet in four raises', 'start': 86.4, 'duration': 3.92}, {'text': 'um and a lot of times they do that', 'start': 88.759, 'duration': 2.761}, {'text':  ...
# [{'text': "Alec Torelli: Hey guys, it's\nAlex Riley and in this video", 'start': 0.51, 'duration': 2.22}, {'text': "we're going to talk about how to\nplay Texas Hold'em. Now this is", 'start': 2.73, 'duration': 3.39}, {'text': 'not a video for the rules\nspecifically but the basic intro', 'start': 6.12, 'duration': 5.22}, {'text': 'strategy', 'start': 11.37, 'duration': 0.78}, {'text': "Welcome to the conscious poker\nYouTube. If you're new here be", 'start': 20.64, 'duration': 2.28}, {'text': 'sure to hit that like and\nsubscribe button because we put', 'start': 22.92, 'duration': 2.64}, {'text': 'out a ton of content to take\nyour poker game to that next', 'start': 25.56, 'duration': 3.03}, {'text': "level. Alright, now let's dive\nin. The first thing you want to", 'start': 28.59, 'duration': 3.15}, {'text': "know about how to play no limit\nHold'em how to play Texas", 'start': 31.74, 'duration': 3.06}, {'text': "Hold'em is just the basic\nstrategy. And the first", 'start': 34.8, 'duration': 4.44}, {'text': 'principle, the first idea you\nwant to keep in mind is position', 'start': 39.33, 'duration': 5.34}, {'text': 'and to be positionally aware,\nand what that basically means is', 'start': 45.45, 'duration': 4.29}, {'text': 'that the position that you are\nin relative to the button will', 'start': 49.92, 'duration': 6.24}, {'text': 'dictate the types of hands that\nyou can play. So there are very', 'start': 56.19, 'duration': 5.79}, {'text': "few hands in poker that you're\ngoing to play Absolutely,", 'start': 61.98, 'duration': 4.47}, {'text': 'regardless of what is called the\nsituation. And the situation', 'start': 66.84, 'duration': 3.78}, {'text': 'basically means the position.\nThose hands are obvious, aces,', 'start': 70.62, 'duration': 4.53}, {'text': "kings, queens, ace king, you're\nalways going to be playing these", 'start': 75.15, 'duration': 3.45}, {'text': 'hands. The rest of the hands,\nthe majority of the hands that', 'start': 78.6, 'duration': 3.63}, {'text': 'you decide to play, in fact,\nwill be based on the position', 'start': 82.23, 'duration': 4.17}, {'text': 'you are in relative to the\nbutton. And the general rule is', 'start': 86.4, 'duration': 4.17}, {'text': 'that the closer you get to being\nin position, meaning the closer', 'start': 90.6, 'duration': 4.08}, {'text': 'you are to the button, the more\nhands you can play. And while', 'start': 94.68, 'duration': 4.2}, {'text': "the exact amount of hands you're\ngoing to play will vary by a lot", 'start': 98.88, 'duration': 3.57}, {'text': 'of factors, like the difficulty\nof your table, the stack sizes,', 'start': 102.45, 'duration': 4.29}, {'text': "if you're playing a tournament,\nit'll be based on how close you", 'start': 106.89, 'duration': 2.67}, {'text': 'are to the money, all sorts of\nother factors that are slightly', 'start': 109.56, 'duration': 2.79}, {'text': 'more advanced. The basic rule is\nthat from the earliest', 'start': 112.35, 'duration': 3.72}, {'text': "positions, you're going to be\nplaying very, very select groups", 'start': 116.07, 'duration': 4.35}, {'text': 'of hands, so only your absolute\nmonsters, your top 10% of hands,', 'start': 120.42, 'duration': 4.44}, {'text': 'you know, pairs like nines are\nbetter and strong suited', 'start': 124.86, 'duration': 3.93}, {'text': 'Broadway hands, you really want\nto be avoiding most offsuit', 'start': 128.79, 'duration': 3.6}, {'text': 'hands with the exception of\nmaybe Ace, King and Ace Queen,', 'start': 132.39, 'duration': 3.21}, {'text': "because they just don't play\nwell, in multi way pots and you", 'start': 135.9, 'duration': 4.05}, {'text': 'have a lot of players behind\nyou. So you have to be very', 'start': 139.95, 'duration': 2.37}, {'text': "cautious. Most more likely than\nnot, if you're unsure about what", 'start': 142.32, 'duration': 4.14}, {'text': 'to do, you should just fold. The\ngeneral rule is if you have a', 'start': 146.46, 'duration': 3.51}, {'text': "hand t ...
# [{'text': "today I'm going to give you 10 gigantic", 'start': 0.04, 'duration': 7.6}, {'text': 'incredibly important mandatory tips that', 'start': 4.12, 'duration': 6.12}, {'text': 'you must fully understand if you want to', 'start': 7.64, 'duration': 6.72}, {'text': "have success at Cash games let's get", 'start': 10.24, 'duration': 8.039}, {'text': 'right to it tip number one is to stop', 'start': 14.36, 'duration': 6.999}, {'text': 'open limping if you open limp on a', 'start': 18.279, 'duration': 6.0}, {'text': 'regular basis in cash games especially', 'start': 21.359, 'duration': 4.881}, {'text': 'if they take a rake out of each pot you', 'start': 24.279, 'duration': 2.881}, {'text': 'will', 'start': 26.24, 'duration': 4.199}, {'text': 'lose okay simple as that an open limp', 'start': 27.16, 'duration': 5.079}, {'text': 'just to be clear is whenever you are the', 'start': 30.439, 'duration': 3.681}, {'text': 'first person to voluntarily put money in', 'start': 32.239, 'duration': 4.201}, {'text': 'the pot so if they Guild the cards small', 'start': 34.12, 'duration': 3.52}, {'text': 'blinds in there big blinds in there', 'start': 36.44, 'duration': 2.6}, {'text': "you're under the gun you're first to act", 'start': 37.64, 'duration': 3.439}, {'text': "if you match the big blind you're going", 'start': 39.04, 'duration': 5.4}, {'text': 'to lose a poker okay stop doing that', 'start': 41.079, 'duration': 4.64}, {'text': 'understand that many of your opponents', 'start': 44.44, 'duration': 3.119}, {'text': 'are going going to do exactly that and', 'start': 45.719, 'duration': 4.121}, {'text': 'that is why they are stuck at the small', 'start': 47.559, 'duration': 5.561}, {'text': 'or medium Stakes games you simply cannot', 'start': 49.84, 'duration': 5.519}, {'text': 'allow all the other players to see the', 'start': 53.12, 'duration': 4.279}, {'text': "flop for only one big blind they're not", 'start': 55.359, 'duration': 4.36}, {'text': 'making a mistake they should call one', 'start': 57.399, 'duration': 3.96}, {'text': 'big B blind very often at that point and', 'start': 59.719, 'duration': 3.441}, {'text': 'play in position against you with', 'start': 61.359, 'duration': 4.241}, {'text': 'anything decent also you let the big', 'start': 63.16, 'duration': 5.08}, {'text': 'blind see the flop for free say they', 'start': 65.6, 'duration': 4.64}, {'text': 'have the Jack four off suit if you raise', 'start': 68.24, 'duration': 4.239}, {'text': 'they have to fold if you limp sometimes', 'start': 70.24, 'duration': 3.8}, {'text': 'they make three of a kind or Jack high', 'start': 72.479, 'duration': 3.64}, {'text': "and that's good enough and that's not", 'start': 74.04, 'duration': 5.56}, {'text': 'what you want to have happen so you need', 'start': 76.119, 'duration': 6.601}, {'text': 'to raise also whenever you L you induce', 'start': 79.6, 'duration': 4.4}, {'text': 'people behind you to raise because', 'start': 82.72, 'duration': 2.2}, {'text': "they're going to think that you have a", 'start': 84.0, 'duration': 3.079}, {'text': 'somewhat weak range and if they think', 'start': 84.92, 'duration': 3.4}, {'text': 'you have a somewhat weak range because', 'start': 87.079, 'duration': 2.36}, {'text': 'they presume you would have raised with', 'start': 88.32, 'duration': 2.759}, {'text': "your best stands well they're going to", 'start': 89.439, 'duration': 2.881}, {'text': 'raise you now you have to play out of', 'start': 91.079, 'duration': 3.32}, {'text': 'position in a slightly larger pod than', 'start': 92.32, 'duration': 3.799}, {'text': "you would like to be in with what's", 'start': 94.399, 'duration': 4.121}, {'text': 'probably not a very good hand also like', 'start': 96.119, 'duration': 6.0}, {'text': 'I said by limping assuming everyone', 'start': 98.52, 'duration': 5.36}, {'text': 'limps behind the casino is going to take', 'start': 102.119, 'duration': 3.801}, {'text': 'a rake out of the pot you do not want to', ...
# [{'text': "what's going on guys Nathan here and", 'start': 0.0, 'duration': 3.3}, {'text': "today I'm going to give you the top nine", 'start': 1.8, 'duration': 4.14}, {'text': 'things that you will never see a good', 'start': 3.3, 'duration': 5.28}, {'text': "Texas Hold'em poker player doing let's", 'start': 5.94, 'duration': 4.44}, {'text': 'jump right into it all right guys so in', 'start': 8.58, 'duration': 4.08}, {'text': 'my 10 plus years as a professional in', 'start': 10.38, 'duration': 4.139}, {'text': 'this game I can tell you that I have', 'start': 12.66, 'duration': 4.619}, {'text': 'never seen a good Texas poker player', 'start': 14.519, 'duration': 5.281}, {'text': 'doing any of the nine things on this', 'start': 17.279, 'duration': 4.561}, {'text': 'list if you see somebody doing one of', 'start': 19.8, 'duration': 3.72}, {'text': "these things you're probably in a good", 'start': 21.84, 'duration': 4.199}, {'text': "poker game AKA you're in a game with", 'start': 23.52, 'duration': 4.2}, {'text': 'some fish in it the people we make the', 'start': 26.039, 'duration': 3.601}, {'text': 'money against so counting down from nine', 'start': 27.72, 'duration': 4.08}, {'text': 'to one here we go number nine is', 'start': 29.64, 'duration': 4.919}, {'text': 're-raising with Ace King especially when', 'start': 31.8, 'duration': 4.56}, {'text': "you hit the top pair on the Flop I'm", 'start': 34.559, 'duration': 3.901}, {'text': 'going to give you an example right now', 'start': 36.36, 'duration': 4.14}, {'text': "just to show you exactly what I'm", 'start': 38.46, 'duration': 3.72}, {'text': 'talking about so you raise up the old', 'start': 40.5, 'duration': 3.78}, {'text': 'days King Ace of Hearts King of Spades', 'start': 42.18, 'duration': 3.96}, {'text': 'and the Flop comes down with a Queen of', 'start': 44.28, 'duration': 4.38}, {'text': 'Spades King of Clubs and jack of', 'start': 46.14, 'duration': 4.259}, {'text': 'diamonds so a lot of beginner and', 'start': 48.66, 'duration': 3.899}, {'text': 'amateur poker players are like wow this', 'start': 50.399, 'duration': 4.921}, {'text': 'is amazing right we got top pair I got', 'start': 52.559, 'duration': 5.101}, {'text': 'the top kicker with the ace I even got a', 'start': 55.32, 'duration': 4.7}, {'text': 'straight drop a 10 comes but guys savvy', 'start': 57.66, 'duration': 4.8}, {'text': 'experienced Texas Holdem players know', 'start': 60.02, 'duration': 5.02}, {'text': 'that this is a dangerous board they know', 'start': 62.46, 'duration': 5.22}, {'text': 'how to read board textures this is', 'start': 65.04, 'duration': 4.259}, {'text': 'something that I talk about a lot in', 'start': 67.68, 'duration': 3.6}, {'text': 'these videos here on the channel is', 'start': 69.299, 'duration': 4.261}, {'text': 'understanding dangerous flops like this', 'start': 71.28, 'duration': 5.82}, {'text': 'one and harmless flops such as a king', 'start': 73.56, 'duration': 6.419}, {'text': 'seven Deuce totally different plot from', 'start': 77.1, 'duration': 4.559}, {'text': "this one so guys if you're up against", 'start': 79.979, 'duration': 3.541}, {'text': 'any kind of decent normal thinking', 'start': 81.659, 'duration': 3.541}, {'text': "opponent who's watching videos like this", 'start': 83.52, 'duration': 4.56}, {'text': 'they make a bet you should be just flat', 'start': 85.2, 'duration': 5.16}, {'text': 'calling in this situation you do not', 'start': 88.08, 'duration': 4.38}, {'text': 'want to be raising and let me explain', 'start': 90.36, 'duration': 4.259}, {'text': 'why right now guys the problem with', 'start': 92.46, 'duration': 4.019}, {'text': 'raising here which again a lot of', 'start': 94.619, 'duration': 3.481}, {'text': 'beginners and amateurs will do because', 'start': 96.479, 'duration': 3.721}, {'text': "whoa whoa I got top pair here it's", 'start': 98.1, 'duration': 4.08}, {'text': "amazing guys the reason why you don't", 'start': 100.2, 'duration': 3 ...
# [{'text': 'and the cheering section on their feet', 'start': 1.16, 'duration': 4.48}, {'text': "if there isn't an eight on the river", 'start': 4.319, 'duration': 3.881}, {'text': "it's all over and we have our champion", 'start': 5.64, 'duration': 7.039}, {'text': "the River card is a four oh it's", 'start': 8.2, 'duration': 7.28}, {'text': 'an that was life-changing money I just F', 'start': 12.679, 'duration': 4.36}, {'text': 'pump the air with both hands that was', 'start': 15.48, 'duration': 3.28}, {'text': "the happiest guy you've ever seen it's", 'start': 17.039, 'duration': 4.361}, {'text': 'just a game of cards an inspiring', 'start': 18.76, 'duration': 5.359}, {'text': "exhilarating game of cards we're not", 'start': 21.4, 'duration': 4.039}, {'text': "saying you're going to be the next", 'start': 24.119, 'duration': 4.521}, {'text': 'hasham the next kid poker the next Money', 'start': 25.439, 'duration': 6.24}, {'text': "Maker although you could be we're not", 'start': 28.64, 'duration': 4.439}, {'text': "saying it's going to change your life", 'start': 31.679, 'duration': 3.001}, {'text': 'get you the millionaire pad in Vegas', 'start': 33.079, 'duration': 4.881}, {'text': 'although it might we just want you to', 'start': 34.68, 'duration': 6.359}, {'text': "play It's the game of kings and queens", 'start': 37.96, 'duration': 5.439}, {'text': 'and has made Champions Legends of both', 'start': 41.039, 'duration': 4.721}, {'text': "men and women think they're glad they", 'start': 43.399, 'duration': 4.64}, {'text': "learned the game but we're getting ahead", 'start': 45.76, 'duration': 4.6}, {'text': "of ourselves slow down let's not run", 'start': 48.039, 'duration': 4.401}, {'text': 'before we can', 'start': 50.36, 'duration': 4.44}, {'text': 'walk we all have to start somewhere', 'start': 52.44, 'duration': 4.32}, {'text': 'people and this series is going to teach', 'start': 54.8, 'duration': 4.239}, {'text': 'you everything you want to know and', 'start': 56.76, 'duration': 4.68}, {'text': "forget the high rooll ERS for now let's", 'start': 59.039, 'duration': 4.601}, {'text': "play the game for the game sake it's", 'start': 61.44, 'duration': 4.679}, {'text': 'supposed to be fun after all tense', 'start': 63.64, 'duration': 6.08}, {'text': 'nerve-wracking pulsating fun stick with', 'start': 66.119, 'duration': 5.841}, {'text': 'us and master this game of nerve this', 'start': 69.72, 'duration': 4.52}, {'text': 'game of will this game of math and', 'start': 71.96, 'duration': 5.159}, {'text': 'precision this fantastic game played the', 'start': 74.24, 'duration': 6.0}, {'text': 'world over are you playing whether', 'start': 77.119, 'duration': 5.601}, {'text': "you're a beginner or Advanced stick", 'start': 80.24, 'duration': 5.76}, {'text': 'around watch the', 'start': 82.72, 'duration': 3.28}, {'text': "show there's no right or wrong with way", 'start': 87.759, 'duration': 4.32}, {'text': "to play poker there's not one method", 'start': 90.04, 'duration': 3.84}, {'text': 'that will guarantee success but there', 'start': 92.079, 'duration': 3.881}, {'text': 'are ways and means for you to maximize', 'start': 93.88, 'duration': 4.199}, {'text': 'your chances of winning there are good', 'start': 95.96, 'duration': 5.08}, {'text': 'habits and bad habits there are', 'start': 98.079, 'duration': 5.521}, {'text': 'situations to avoid and situations to', 'start': 101.04, 'duration': 4.84}, {'text': 'seek and there are those who have the', 'start': 103.6, 'duration': 4.28}, {'text': "knowledge to exploit them we're going to", 'start': 105.88, 'duration': 4.04}, {'text': 'teach you how to master the game from', 'start': 107.88, 'duration': 3.32}, {'text': 'the', 'start': 109.92, 'duration': 4.15}, {'text': 'basics to the advanced', 'start': 111.2, 'duration': 10.28}, {'text': '[Music]', 'start': 114.07, 'duration': 7.41}, {'text': "let's start at the beginning ladies and", 'start': 124.479, 'duration': 4.041}, {'text': "g ...
# [{'text': 'multioutput R for YouTube instead of', 'start': 0.88, 'duration': 4.519}, {'text': 'stream', 'start': 3.439, 'duration': 4.281}, {'text': "elements see if that works we'll see if", 'start': 5.399, 'duration': 6.401}, {'text': 'at least it displays the chat', 'start': 7.72, 'duration': 4.08}, {'text': '[Music]', 'start': 13.27, 'duration': 3.13}, {'text': "you know what let's put that up here", 'start': 39.84, 'duration': 4.08}, {'text': 'that looks', 'start': 60.039, 'duration': 2.401}, {'text': 'good there we', 'start': 68.6, 'duration': 5.36}, {'text': 'go and then we did get a deal with juren', 'start': 70.6, 'duration': 5.36}, {'text': 'now hopefully that will show up', 'start': 73.96, 'duration': 3.839}, {'text': 'correctly', 'start': 75.96, 'duration': 4.839}, {'text': 'too', 'start': 77.799, 'duration': 3.0}, {'text': 'um it should show on the juren page uh', 'start': 81.6, 'duration': 5.04}, {'text': 'let me send them oh there we go we got', 'start': 85.119, 'duration': 3.161}, {'text': 'in on our table [\xa0__\xa0]', 'start': 86.64, 'duration': 5.119}, {'text': "yeah let's uh send them my link to", 'start': 88.28, 'duration': 6.479}, {'text': 'Twitch', 'start': 91.759, 'duration': 3.0}, {'text': 'spe', 'start': 142.72, 'duration': 3.0}, {'text': "let's", 'start': 152.76, 'duration': 2.32}, {'text': 'see', 'start': 159.56, 'duration': 3.0}, {'text': 'um', 'start': 175.959, 'duration': 8.761}, {'text': "um don't know why that is uh", 'start': 178.84, 'duration': 5.88}, {'text': "all right so let's uh", 'start': 227.36, 'duration': 4.68}, {'text': "let's see", 'start': 243.799, 'duration': 3.321}, {'text': "all right let's see getting in a hand", 'start': 277.28, 'duration': 5.359}, {'text': 'here shortly good I always wait for the', 'start': 280.199, 'duration': 5.641}, {'text': 'big blind', 'start': 282.639, 'duration': 3.201}, {'text': "there we go and looks like we're good on", 'start': 306.96, 'duration': 2.32}, {'text': 'YouTube', 'start': 308.24, 'duration': 3.799}, {'text': 'now see if it shows I one in chat though', 'start': 309.28, 'duration': 5.04}, {'text': 'on', 'start': 312.039, 'duration': 2.281}, {'text': '[Applause]', 'start': 318.47, 'duration': 4.49}, {'text': 'stream not look like chat is uh it does', 'start': 319.919, 'duration': 5.321}, {'text': 'not look like twitch or uh YouTube chat', 'start': 322.96, 'duration': 5.079}, {'text': 'is working on stream yet so um I will', 'start': 325.24, 'duration': 4.679}, {'text': "monitor it but uh if you're on YouTube", 'start': 328.039, 'duration': 3.361}, {'text': 'unfortunately will not show up on stream', 'start': 329.919, 'duration': 6.161}, {'text': "for this broadcast but I'll fix it after", 'start': 331.4, 'duration': 4.68}, {'text': '[Music]', 'start': 351.72, 'duration': 3.069}, {'text': 'oh we got King 10 and someone', 'start': 363.72, 'duration': 4.8}, {'text': 'just three [\xa0__\xa0] went all in all right', 'start': 365.639, 'duration': 6.56}, {'text': 'then old no problem no', 'start': 368.52, 'duration': 6.56}, {'text': 'problem ah cool and look at that it', 'start': 372.199, 'duration': 4.601}, {'text': 'shows up on geur and I got to take a', 'start': 375.08, 'duration': 4.519}, {'text': 'picture of that that is pretty [\xa0__\xa0]', 'start': 376.8, 'duration': 7.28}, {'text': 'neat I must say', 'start': 379.599, 'duration': 4.481}, {'text': '[Music]', 'start': 399.25, 'duration': 3.17}, {'text': "where's my", 'start': 420.919, 'duration': 2.441}, {'text': 'mouse all right now I do need to post', 'start': 430.28, 'duration': 4.359}, {'text': 'the', 'start': 432.479, 'duration': 2.16}, {'text': 'link fold if if everyone folded we would', 'start': 437.919, 'duration': 4.521}, {'text': 'have uh or if everyone folded we would', 'start': 440.8, 'duration': 4.2}, {'text': 'have opened but uh since he did open it', 'start': 442.44, 'duration': 5.24}, {'text': 'we do fold a 7', 'start': 445.0, 'duration': 7.84}, {'text': 'offit from uh cut  ...
# [{'text': '[Music]', 'start': 0.6, 'duration': 3.64}, {'text': 'this video will teach you the most', 'start': 2.919, 'duration': 3.36}, {'text': 'popular version of Poker played all over', 'start': 4.24, 'duration': 4.6}, {'text': 'the world Texas Holden the objective of', 'start': 6.279, 'duration': 6.081}, {'text': "the game to win your opponent's chips a", 'start': 8.84, 'duration': 5.28}, {'text': 'table can consist of anywhere between', 'start': 12.36, 'duration': 4.16}, {'text': "two to 10 players for this video let's", 'start': 14.12, 'duration': 4.6}, {'text': 'give this table six', 'start': 16.52, 'duration': 4.32}, {'text': 'players one player needs to be the', 'start': 18.72, 'duration': 3.84}, {'text': "dealer in our example it's going to be", 'start': 20.84, 'duration': 3.92}, {'text': 'player number one most of the time', 'start': 22.56, 'duration': 3.559}, {'text': "you'll see a dealer button next to the", 'start': 24.76, 'duration': 4.24}, {'text': 'dealer player a poked dealer distributes', 'start': 26.119, 'duration': 4.681}, {'text': 'cards to players and manages the action', 'start': 29.0, 'duration': 3.719}, {'text': 'at a Pok', 'start': 30.8, 'duration': 4.4}, {'text': 'table to the left of the dealer we will', 'start': 32.719, 'duration': 4.921}, {'text': 'always find the small and big blind the', 'start': 35.2, 'duration': 4.4}, {'text': 'purpose of these blind bets is to create', 'start': 37.64, 'duration': 4.599}, {'text': 'the starting pot the players in spaces', 'start': 39.6, 'duration': 4.76}, {'text': 'two and three will be required to put', 'start': 42.239, 'duration': 3.881}, {'text': 'money into the pot before they even see', 'start': 44.36, 'duration': 3.76}, {'text': "what cards they're", 'start': 46.12, 'duration': 4.68}, {'text': 'given after that every player is given', 'start': 48.12, 'duration': 5.599}, {'text': 'two cards face down clockwise of the', 'start': 50.8, 'duration': 5.32}, {'text': 'dealer each player can only look at his', 'start': 53.719, 'duration': 3.64}, {'text': 'own', 'start': 56.12, 'duration': 3.36}, {'text': 'cards after the cards have been dealt', 'start': 57.359, 'duration': 3.52}, {'text': 'and the small big blinds put on the', 'start': 59.48, 'duration': 3.399}, {'text': 'table the player to the left of the big', 'start': 60.879, 'duration': 4.721}, {'text': "blind is First Act our example it's", 'start': 62.879, 'duration': 5.681}, {'text': 'going to be player number', 'start': 65.6, 'duration': 2.96}, {'text': 'four the first round of betting ensues', 'start': 69.04, 'duration': 3.96}, {'text': 'there are three potential moves', 'start': 71.88, 'duration': 3.12}, {'text': 'available to each player here players', 'start': 73.0, 'duration': 4.08}, {'text': "can either call which means that they'll", 'start': 75.0, 'duration': 3.799}, {'text': 'put out an amount of chips into the PO', 'start': 77.08, 'duration': 5.32}, {'text': 'equal to the BET of the previous', 'start': 78.799, 'duration': 3.601}, {'text': 'player they can alternatively raise and', 'start': 83.439, 'duration': 3.841}, {'text': 'put in an amount of chips that is bigger', 'start': 85.72, 'duration': 3.84}, {'text': 'than the previous bet or they can fold', 'start': 87.28, 'duration': 3.68}, {'text': 'they can give away their cards and their', 'start': 89.56, 'duration': 3.559}, {'text': "involvement in the current hand let's", 'start': 90.96, 'duration': 6.36}, {'text': 'see what everyone does here player four', 'start': 93.119, 'duration': 7.04}, {'text': 'raises player five', 'start': 97.32, 'duration': 5.479}, {'text': 'calls player six', 'start': 100.159, 'duration': 5.441}, {'text': 'calls player one', 'start': 102.799, 'duration': 5.041}, {'text': 'calls player two', 'start': 105.6, 'duration': 5.76}, {'text': 'calls and player three calls notice that', 'start': 107.84, 'duration': 5.639}, {'text': 'players two and three put chips in again', 'start': 111.36, 'duration': 3.2}, {'text': "eve ...

# %% [markdown]
# ### Store information to DynamoDB

# %%
AWS_ACCESS_KEY_ID
# Out:
# 'poker_db'

# %%
import boto3
from botocore.exceptions import ClientError


# 初始化 DynamoDB 客户端
dynamodb = boto3.resource(
    'dynamodb',
    aws_access_key_id=AWS_ACCESS_KEY_ID,  # 替换为你的 Access Key
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,  # 替换为你的 Secret Key
    region_name='us-east-1'  # 替换为你的区域
)

# 表名
table_name = "youtube_poker_db"

# %%
table = dynamodb.Table(table_name)
table.table_status
# Out:
# 'ACTIVE'

# %%
def insert_video_metadata(table_name,video_id, title, url, transcript):
    """
    将视频元数据插入到 DynamoDB 表中
    :param video_id: 视频的唯一 ID
    :param title: 视频标题
    :param url: 视频 URL
    :param transcript: 视频转录文本
    """
    table = dynamodb.Table(table_name)
    try:
        table.put_item(
            Item={
                "VideoID": video_id,  # Partition Key
                "Title": title,
                "URL": url,
                "Transcript": transcript
            }
        )
        print(f"Video {video_id} metadata inserted successfully.")
    except ClientError as e:
        print(f"Error inserting metadata: {e.response['Error']['Message']}")

# %%
def insert_video_metadata_batch(query, table_name, max_results=10):
    """
    批量插入视频元数据到 DynamoDB
    """
    success_count = 0
    error_count = 0
    
    try:
        # 首先验证 AWS 认证
        table = dynamodb.Table(table_name)
        table.table_status  # 测试连接
        
        # 获取视频列表
        videos = search_youtube_videos(query, max_results)
        print(f"找到 {len(videos)} 个视频")
        
        for video in videos:
            try:
                # 获取转录文本
                transcript_text = get_transcript(video['video_id'])
                
                # 插入数据
                insert_video_metadata(
                    table_name,
                    video['video_id'],
                    video['title'],
                    video['url'],
                    transcript_text  # 现在传入的是字符串
                )
                success_count += 1
                print(f"成功插入视频: {video['title']}")
                
            except Exception as e:
                error_count += 1
                print(f"处理视频时出错: {str(e)}")
                
        print(f"\n插入总结:")
        print(f"成功: {success_count}")
        print(f"失败: {error_count}")
        
    except Exception as e:
        print(f"严重错误: {str(e)}")
        print("请检查 AWS 认证设置")
        
    return success_count, error_count

# %%
insert_video_metadata_batch(query,table_name,200)
# Out:
# 已获取 50 个视频...
# 已获取 100 个视频...
# 已获取 150 个视频...
# 已获取 200 个视频...
# 总共获取 200 个视频
# 找到 200 个视频
# Video eAJG5q-_OoU metadata inserted successfully.
# 成功插入视频: This Easy No Limit Hold&#39;em Strategy SKYROCKETED My Winnings
# Video aJ3rfNH-yGY metadata inserted successfully.
# 成功插入视频: Win More at Poker - Easy Strategy for Hold&#39;em Starting Hands
# Video pSRGErzzIo4 metadata inserted successfully.
# 成功插入视频: How to Play Poker for Beginners | PokerStars Learn
# Video -cu4kQhARJI metadata inserted successfully.
# 成功插入视频: How to Play Limit Hold&#39;em
# Video bcKjZq43NjE metadata inserted successfully.
# 成功插入视频: How to Play No Limit Texas Hold’em (5 Beginner Poker Strategies)
# Video noKz7aCfwNM metadata inserted successfully.
# 成功插入视频: 9 TEXAS HOLD&#39;EM Poker Tips For Beginners (Just Do This!)
# Video GAoR9ji8D6A metadata inserted successfully.
# 成功插入视频: 🎒 📈 How to Play Poker - Texas Hold&#39;em Rules Made Easy
# Video f-MnvLLYqPE metadata inserted successfully.
# 成功插入视频: TOP 10 Cash Game TIPS! [Master The Fundamentals]
# Video EKB-qfS5CfY metadata inserted successfully.
# 成功插入视频: Mid-stakes grind on Coin Poker 25nl | 50nl | 100nl | Texas Holdem Poker | NLE | Poker
# Video ZuK0huIhr3A metadata inserted successfully.
# 成功插入视频: No Limit Texas Hold&#39;em Basics - Everything Poker [Ep. 01] | PokerStars
# Video YkSuH5K5s_A metadata inserted successfully.
# 成功插入视频: Poker Strategy -- Low-Stakes Limit Hold&#39;Em with Jimmy Fricke
# Video V4qGEcJ449s metadata inserted successfully.
# 成功插入视频: Poker Strategy -- Greg Mueller On Hand Selection In Limit Hold&#39;Em
# Video 8HAvoD4wTLQ metadata inserted successfully.
# 成功插入视频: Poker Strategy -- Limit Hold&#39;em with Maria Ho
# Video HVCc1hSxYUk metadata inserted successfully.
# 成功插入视频: Poker Strategy for LATE Position #PokerTips #TexasHoldem #pokerstars
# Video YQoNJ3TvLQs metadata inserted successfully.
# 成功插入视频: Strategy: Limit Hold&#39;Em with Matt &quot;Hoss_TBF&quot; Hawrilenko
# Video 0Q-pNG5so98 metadata inserted successfully.
# 成功插入视频: This Easy Cash Game Strategy SKYROCKETED My Winnings
# Video QqXzTxxMzjU metadata inserted successfully.
# 成功插入视频: Poker Strategy MATH Every Pro Knows
# Video b9HYxquQt-M metadata inserted successfully.
# 成功插入视频: How to Play Texas Hold&#39;em | Beginners Guide | PokerNews
# Video XPfZLTjTdvM metadata inserted successfully.
# 成功插入视频: Poker Strategy -- Limit Hold&#39;Em With Ali Eslami
# Video AX-8f7Aoqpo metadata inserted successfully.
# 成功插入视频: How to play Texas Hold’em Poker in 60 seconds #PokerTips #Poker #PokerStrategy
# Video ow51TAILgL8 metadata inserted successfully.
# 成功插入视频: 10 Tips to Master No-Limit Hold&#39;em Preflop Strategy
# Video xv-kx1gO3kY metadata inserted successfully.
# 成功插入视频: Strategy: Limit Hold&#39;em
# Video n-MG0gzXwis metadata inserted successfully.
# 成功插入视频: Poker Hands: A list and explanation of the rankings  | PokerStars Learn
# Video bSXtZBLisMI metadata inserted successfully.
# 成功插入视频: Tips &amp; Tricks to Beat LOW STAKES POKER! $1/2, $1/3, $2/5 | Poker Vlog #251
# Video ZOSLuOli3BA metadata inserted successfully.
# 成功插入视频: How to Win at Texas Hold&#39;em Every Time (Just Do This!)
# Video Ix4QxqCtUCs metadata inserted successfully.
# 成功插入视频: 5 Basic Poker Strategies EVERY Beginner Should Know
# Video ibkt_SLQe4E metadata inserted successfully.
# 成功插入视频: How To Bet In Poker | PokerStars Learn
# Video lYZ1nqXUk0g metadata inserted successfully.
# 成功插入视频: POKER advice from NEGREANU
# Video 9wuW27SNhHo metadata inserted successfully.
# 成功插入视频: 100 ESSENTIAL Tips To Master No Limit Hold&#39;em!
# Video FYvZqz2QcCs metadata inserted successfully.
# 成功插入视频: How to Bet on Limit Poker | Gambling Tips
# 获取字幕失败:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Opl3Io1fM8k! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (Opl3Io1fM8k) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
#  - en-US ("English (United States)")[TRANSLATABLE]
#
# (GENERATED)
# None
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Video Opl3Io1fM8k metadata inserted successfully.
# 成功插入视频: 7 Tournament Tips to Help You Run Deep | Upswing Poker Level-Up
# Video KboIfWmFuTM metadata inserted successfully.
# 成功插入视频: How to Play:  Limit Texas Hold &#39;Em
# Video z9Kfy3lhkAg metadata inserted successfully.
# 成功插入视频: Top 5 Low Stakes Poker Hacks
# Video h5azci4-TL8 metadata inserted successfully.
# 成功插入视频: POKER CONCEPTS in Action: Ranges, Bluffs, Bubble Play and getting All In
# Video KpChdURVlfo metadata inserted successfully.
# 成功插入视频: How to Realistically Win at Poker as a Beginner (2024)
# Video LlLqznwk7yE metadata inserted successfully.
# 成功插入视频: This Easy Texas Hold&#39;em Strategy SKYROCKETED My Winnings
# Video _9eDNDASQpo metadata inserted successfully.
# 成功插入视频: Mastering the Fundamentals: Preflop Strategy
# Video zLKgRi912FA metadata inserted successfully.
# 成功插入视频: HOW TO PLAY ULTIMATE TEXAS HOLD&#39;EM! MY STRATEGY AND COMPLETE BREAKDOWN OF THE GAME!
# Video p6Ue_Bu5DmU metadata inserted successfully.
# 成功插入视频: 9 Poker Strategies EVERY Serious Player Should Know
# Video QTMhuD0XEcY metadata inserted successfully.
# 成功插入视频: Top 5 Reasons You&#39;re Losing at Poker
# Video awpfHL3CmOk metadata inserted successfully.
# 成功插入视频: How to Bluff in Poker - Texas Holdem Poker Strategy - Bluffing Lesson
# Video ODVg8sf76Yg metadata inserted successfully.
# 成功插入视频: No Limit Texas Holdem Rules &amp; Gameflow Crash Course
# Video l_tBnX8tNp8 metadata inserted successfully.
# 成功插入视频: How to Crush $2/$5 No Limit Hold&#39;em (In 8 Weeks)
# Video GE8BGWjUDYs metadata inserted successfully.
# 成功插入视频: The ULTIMATE Poker Tips Compilation (3+ Hours!)
# Video 88ra7EnkJkE metadata inserted successfully.
# 成功插入视频: Try This Simple Strategy for Paired Flops (Works Instantly!) #poker #shorts
# Video _oF1MdZ6k30 metadata inserted successfully.
# 成功插入视频: Poker Betting Rules No1
# Video B1JjmsekmqI metadata inserted successfully.
# 成功插入视频: Mastering The Fundamentals: Postflop Strategy
# Video 3kyGYtHcvpA metadata inserted successfully.
# 成功插入视频: The ONLY Poker Strategy Video You Will Ever Need *FULL COURSE*
# Video ZKCQ6tJ4qIQ metadata inserted successfully.
# 成功插入视频: Making $100/hr in TEXAS POKER!! Dominating LOW STAKES! | Poker Vlog #215
# Video L7wYqVqpapo metadata inserted successfully.
# 成功插入视频: How to MAKE $3500 in less than a minute #pokervlog #poker #texasholdem #pokerpro #pokerstars #shorts
# Video L7wYqVqpapo metadata inserted successfully.
# 成功插入视频: How to MAKE $3500 in less than a minute #pokervlog #poker #texasholdem #pokerpro #pokerstars #shorts
# Video HvVuUziNERQ metadata inserted successfully.
# 成功插入视频: How to spot a poker tell in SECONDS! #Poker.
# Video GbU129Oaxdo metadata inserted successfully.
# 成功插入视频: The Most Underrated Hand In Poker...
# Video Ay05K429tRE metadata inserted successfully.
# 成功插入视频: Texas Holdem Rules For Dummies!
# Video yQCIylvEDDQ metadata inserted successfully.
# 成功插入视频: How to Win at Poker Every Time (Just Do This!)
# Video OHFDITnIo7Y metadata inserted successfully.
# 成功插入视频: #1 PLO Tip for No Limit Holdem Players (NLH ▶️ PLO)
# Video OD12wpuh634 metadata inserted successfully.
# 成功插入视频: 9 PREFLOP Poker Tips For Beginners (Just Do This!)
# Video O7w7w5vgFk8 metadata inserted successfully.
# 成功插入视频: #1 Exploit to CRUSH $1/$2 Live No Limit Cash Games
# Video GE7qGgosaqo metadata inserted successfully.
# 成功插入视频: How to Deal Texas Hold&#39;em Poker
# 获取字幕失败:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=5P0OMrg2okQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Video 5P0OMrg2okQ metadata inserted successfully.
# 成功插入视频: Poker Pro Maria Ho&#39;s Top 5 Strategy Tips for Poker Tournaments
# Video 54LMoQTUZ1I metadata inserted successfully.
# 成功插入视频: 16 Easy Poker Tips for BEGINNERS (Free Course)
# Video E_fAWuj7DDI metadata inserted successfully.
# 成功插入视频: Why is Texas hold &#39;em so popular? - James McManus
# Video aSFWBjxsuZA metadata inserted successfully.
# 成功插入视频: Mastering The Fundamentals: Cash Game Strategy
# Video qKuFPn88Gg0 metadata inserted successfully.
# 成功插入视频: Basic Strategy for Ultimate Texas Holdem
# Video nWYSfXreH6M metadata inserted successfully.
# 成功插入视频: How To Deal Texas Holdem Poker Professionally - Texas Holdem Poker Dealing Training Video
# Video 8D5krOLGPjE metadata inserted successfully.
# 成功插入视频: Complete Beginner&#39;s Guide to Poker - Learn Texas Hold Em!
# Video bdNA3m1t2yQ metadata inserted successfully.
# 成功插入视频: How to Play Ultimate Texas Hold &#39;em
# Video Eimf0ExhSjM metadata inserted successfully.
# 成功插入视频: 5 Step Guide to CRUSH Low Stakes Poker (2024)
# Video OyLe4mbGAEk metadata inserted successfully.
# 成功插入视频: 5 Poker Hands Good Players Know to NEVER Play
# Video v8dqu_aVQk8 metadata inserted successfully.
# 成功插入视频: How to Play Texas Holdem Poker
# Video 0m3FypX7Uk8 metadata inserted successfully.
# 成功插入视频: The Power of Position - Basic Poker Strategy
# Video J1LodFZtAKM metadata inserted successfully.
# 成功插入视频: How To Play Pot Limit Omaha
# Video ZRTGcJhvp2w metadata inserted successfully.
# 成功插入视频: How to Run Deep in Poker Tournaments
# Video otXKdS7q02o metadata inserted successfully.
# 成功插入视频: Most Insane Poker Hands #14 #pokerpro #pokeronline #pokershorts #pokerstars #poker
# Video a_EJas4VQgQ metadata inserted successfully.
# 成功插入视频: Hand Breakdowns, Strategy, and Analysis from the 2021 WSOP Part 1
# Video _7YKg7qBY4M metadata inserted successfully.
# 成功插入视频: Simple Trick to Win Poker Tournaments (Works Every Time!)
# Video 7Q1VLRptYWU metadata inserted successfully.
# 成功插入视频: Poker Basics: How To Compete In No Limit Texas Hold Em
# Video JOomXP-r1wY metadata inserted successfully.
# 成功插入视频: How To Play Poker - Learn Poker Rules: Texas hold em rules
# Video f7rLc7mx000 metadata inserted successfully.
# 成功插入视频: Poker Ranges Explained
# Video 3JfDDf3hOK8 metadata inserted successfully.
# 成功插入视频: 8 ADVANCED Poker Tips For PREFLOP
# Video Vx0iJ7h_b8o metadata inserted successfully.
# 成功插入视频: GTO Explained in Under 10 Minutes
# Video Y3-fkNpoLU8 metadata inserted successfully.
# 成功插入视频: Funniest Thing Yet #poker #pokerstars #texasholdem
# Video OhhW95nsBWg metadata inserted successfully.
# 成功插入视频: Texas Hold&#39;em Poker - Why &amp; How to play No Limit Texas Holdem Poker
# Video fDBte-h4nSQ metadata inserted successfully.
# 成功插入视频: Poker Position Explained - What is Position in Poker? - Poker Position Names Strategy Tips
# Video NUso9Q53TzU metadata inserted successfully.
# 成功插入视频: Plug These 5 Poker Tournament Leaks NOW (and Start Winning!)
# Video EhMearHy9gY metadata inserted successfully.
# 成功插入视频: 7 Basic Poker Tips EVERY Beginner Should Know About
# Video Lt5GRTsCLZQ metadata inserted successfully.
# 成功插入视频: TRYING TO SURVIVE $2/$5 pt 2 // Texas Holdem Poker Vlog 32
# Video tBxLj4z96Ws metadata inserted successfully.
# 成功插入视频: How To Play The Flop (NLH) - Winning Poker Strategy
# Video cNaUXwu4MzQ metadata inserted successfully.
# 成功插入视频: 📈 🃁 Poker Hands Ranking in Texas Hold&#39;em
# Video 5eQ2k4SJOCo metadata inserted successfully.
# 成功插入视频: POT ODDS &amp; EQUITY In POKER [5 TIPS To Use Them At The Table]
# Video 1jo17-hzVXM metadata inserted successfully.
# 成功插入视频: How to WIN at POKER in 2024!
# Video ebsttLnOIpg metadata inserted successfully.
# 成功插入视频: Learn The STRADDLE Bet! - Poker Strategies
# Video _nYsZ_njLeE metadata inserted successfully.
# 成功插入视频: Poker Nights Minimum Raising with Blake Pelton
# Video Vy06LLOOGkY metadata inserted successfully.
# 成功插入视频: 3 HACKS To BUILD A BIG Stack! [Poker Tournament Strategy]
# Video xERRYsLVNxw metadata inserted successfully.
# 成功插入视频: Daniel Negreanu in $5,470,800 Online Poker Tournament!
# Video HbXt1jRBYrc metadata inserted successfully.
# 成功插入视频: HOW TO DOMINATE LOW STAKES POKER!! | Wolfmas Day #3
# Video npkjZcUEXEA metadata inserted successfully.
# 成功插入视频: Starting Hand Selection [Preflop Poker Strategy]
# Video Nvx9DjIWJj4 metadata inserted successfully.
# 成功插入视频: Pot Limit Omaha Strategy - 5 pro tips
# Video 2Ln7WxrfYGI metadata inserted successfully.
# 成功插入视频: $3.1 Million Dollar hand makes history! #PokerShortd #Poker
# Video yWiiQQ59r4w metadata inserted successfully.
# 成功插入视频: How to Bluff in Poker like a Pro | PokerStars Learn
# Video npkjZcUEXEA metadata inserted successfully.
# 成功插入视频: Starting Hand Selection [Preflop Poker Strategy]
# Video YU1_IW67oJ8 metadata inserted successfully.
# 成功插入视频: HOW to BEAT 1/2 live poker!!  // Poker Vlog #9
# Video C7ISlaGJBeI metadata inserted successfully.
# 成功插入视频: How to Play Texas Hold&#39;em Poker - Live Poker Basics Tutorials
# Video 1GAs8qhfzEQ metadata inserted successfully.
# 成功插入视频: Ultimate Texas Holdem Basic Strategy! #shorts
# Video HIgMe_Sg0HY metadata inserted successfully.
# 成功插入视频: Genius Way To NEVER LOSE Online Poker
# Video HbXt1jRBYrc metadata inserted successfully.
# 成功插入视频: HOW TO DOMINATE LOW STAKES POKER!! | Wolfmas Day #3
# Video MgnMxTjKxp4 metadata inserted successfully.
# 成功插入视频: 3 BIG Mistakes To AVOID In $1/$2 Live Cash Games
# Video yWiiQQ59r4w metadata inserted successfully.
# 成功插入视频: How to Bluff in Poker like a Pro | PokerStars Learn
# Video D4NSdpzNkp4 metadata inserted successfully.
# 成功插入视频: 5 Tips to RUN DEEP in More Tournaments
# Video Dw7pCbNOfEU metadata inserted successfully.
# 成功插入视频: 5 Easy Poker Strategies EVERY Beginner Should Know
# Video e6rrK3VJuOw metadata inserted successfully.
# 成功插入视频: 11 Texas Hold &#39;em Strategies for winning Poker Tournaments.
# Video QRMKQxq8lzc metadata inserted successfully.
# 成功插入视频: Top 5 Most EPIC Poker Hands You Must Have Seen ♠️ PokerStars
# Video l0Dn5Oc_g6Y metadata inserted successfully.
# 成功插入视频: Poker Rules and Etiquette for Beginners | PokerStars Learn
# Video Nvx9DjIWJj4 metadata inserted successfully.
# 成功插入视频: Pot Limit Omaha Strategy - 5 pro tips
# Video Ts8Yh2DZA1Y metadata inserted successfully.
# 成功插入视频: $4,727,000 ON THE TABLE [Huge Poker Tournament]
# Video 28KR2hXowCU metadata inserted successfully.
# 成功插入视频: Biggest Texas Holdem Cash Game Pots of 2022 with Daniel Negreanu, Eric Persson &amp; Bryn Kenney
# Video LF7Y2Kbf4Jo metadata inserted successfully.
# 成功插入视频: Becoming a $1/3 No Limit POKER PRO?!?
# Video lmVUd-Pcz54 metadata inserted successfully.
# 成功插入视频: Mastering Position in Poker: The Key to Winning Big! How to Play Poker for Beginners.
# Video r1gubhDi7Xc metadata inserted successfully.
# 成功插入视频: From FANBOY To FINAL TABLE - The Incredible Story of Sebastian Malec | PART 4 #EPT #SebastianMalec
# Video vIfxEDLQUNs metadata inserted successfully.
# 成功插入视频: Making $100/Hour Playing 1/2 in TEXAS!! | POKER VLOG #23
# Video CaaJsmO5W6g metadata inserted successfully.
# 成功插入视频: Don&#39;t Give Phil Ivey Any Room to Bluff
# Video D8gf1Altqqs metadata inserted successfully.
# 成功插入视频: Handling All In #Poker Bets and Calculating Side Pots | SuperDealer Lesson 19
# Video 0m0gGut6e20 metadata inserted successfully.
# 成功插入视频: 9 Easy Poker Strategies EVERY Decent Player Should Know
# Video uC5XS_5CBzo metadata inserted successfully.
# 成功插入视频: 3 HACKS for Crushing Low Stakes Cash Games
# Video P2OQImaJGL8 metadata inserted successfully.
# 成功插入视频: GTO vs Exploitative Play - Poker Tips with Daniel Negreanu
# Video cNaUXwu4MzQ metadata inserted successfully.
# 成功插入视频: 📈 🃁 Poker Hands Ranking in Texas Hold&#39;em
# Video BiGf4XXXRvI metadata inserted successfully.
# 成功插入视频: THE BEST HAND IN POKER!! ALL-IN w/ POCKET ACES!! #shorts #poker
# Video 9l101Gg81o8 metadata inserted successfully.
# 成功插入视频: Chris Ferguson: Low Limit Strategy
# 获取字幕失败:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=8LK0m01rxcI! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (8LK0m01rxcI) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
#  - en-US ("English (United States)")[TRANSLATABLE]
#
# (GENERATED)
# None
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Video 8LK0m01rxcI metadata inserted successfully.
# 成功插入视频: Doug Polk&#39;s 30 Min Guide to Heads-Up Poker | Upswing Poker Level-Up
# Video j9oEWTfXy9I metadata inserted successfully.
# 成功插入视频: No limit Texas Holdem tips
# Video _32aQ-A6Iw8 metadata inserted successfully.
# 成功插入视频: 10 Tips to Help You Win at Texas Hold &#39;em Poker.
# Video -hquZ2ZKcXM metadata inserted successfully.
# 成功插入视频: EARLY STAGE STRATEGY 6-Max Poker Tournament with Daniel Negreanu
# Video 7CxArFkAW-w metadata inserted successfully.
# 成功插入视频: TRYING to play ANY SUITED cards in No Limit Texas Holdem #poker #lasvegas #poker
# Video hyVxkphchEY metadata inserted successfully.
# 成功插入视频: TWO Players FLOP A FLUSH 🤯 #flush #poker
# Video o__N-BbVcmg metadata inserted successfully.
# 成功插入视频: Poker Tournament Strategy | Poker Tutorial with @Spraggy | PokerStars Learn
# Video S_h9EEzBoYU metadata inserted successfully.
# 成功插入视频: Risking $10,000 For The Ultimate Texas Hold Em&#39; Experience!
# Video RYAY0PwO3lo metadata inserted successfully.
# 成功插入视频: Defending your Blinds
# Video JV91VEjaMtw metadata inserted successfully.
# 成功插入视频: HOW to BEAT 1/2 Live Poker!!
# Video dU4_6Bskqps metadata inserted successfully.
# 成功插入视频: The 5 best tips to win at poker in 2021 | [Texas Hold&#39;em]
# Video mfmv3FbMs5Q metadata inserted successfully.
# 成功插入视频: Big Blind Ante Poker Explained!
# Video aoYAAnPnngw metadata inserted successfully.
# 成功插入视频: 9 Easy Ways to Tell if They Are Bluffing You
# Video HcDcht4v3F0 metadata inserted successfully.
# 成功插入视频: I PLAY ULTIMATE TEXAS HOLDEM! (With Mom!!)
# Video Jf5fc1rPCHI metadata inserted successfully.
# 成功插入视频: How to DOMINATE a Low Stakes Poker Game
# Video YR8wUjsvAAY metadata inserted successfully.
# 成功插入视频: 🔴ULTIMATE TEXAS HOLD EM! BEST $E$$ION EVER?! 💲NEW VIDEO DAILY!
# Video 9a5HtI5HU64 metadata inserted successfully.
# 成功插入视频: Daniel Negreanu&#39;s Bluff Got Called By... WHAT?!! 💢
# Video 45cTE7MVxJA metadata inserted successfully.
# 成功插入视频: You should never do this playing live poker! @razepoker3227 #poker #gamble #pokeronline
# Video yeDR9zgb-zE metadata inserted successfully.
# 成功插入视频: Chasing a Royal Flush in Texas Hold’em Poker 💰#RoyalFlush #PokerTips #PokerVlog #PokerPlayer
# 获取字幕失败:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=pwvJRWgSp90! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (pwvJRWgSp90) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
#  - en-US ("English (United States)")[TRANSLATABLE]
#
# (GENERATED)
# None
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Video pwvJRWgSp90 metadata inserted successfully.
# 成功插入视频: Pot Limit Omaha Is INCREDIBLY Easy | Upswing Poker Level-Up
# Video 8ay2xxUxHEI metadata inserted successfully.
# 成功插入视频: Don&#39;t play live poker for the first time without watching this! Poker terms and mechanics intro
# Video ynXyLQArlOk metadata inserted successfully.
# 成功插入视频: Mastering The Fundamentals: Preflop Tournament Strategy
# 获取字幕失败:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ra06-ozcArY! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (ra06-ozcArY) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
#  - en-US ("English (United States)")[TRANSLATABLE]
#
# (GENERATED)
# None
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Video ra06-ozcArY metadata inserted successfully.
# 成功插入视频: STOP Spewing Your Chips in Poker Tournaments | Upswing Poker Level-Up
# Video y2W8-AhrmMU metadata inserted successfully.
# 成功插入视频: How to Deal Poker Like a Pro in 7 Easy Steps
# Video qUdU1-oCYVY metadata inserted successfully.
# 成功插入视频: ULTIMATE Texas Hold&#39;em - Full Guide!
# Video QBTqPOvVW28 metadata inserted successfully.
# 成功插入视频: How to deal with AGGRESSIVE PLAYERS!
# Video yeDR9zgb-zE metadata inserted successfully.
# 成功插入视频: Chasing a Royal Flush in Texas Hold’em Poker 💰#RoyalFlush #PokerTips #PokerVlog #PokerPlayer
# Video su61vuClbBI metadata inserted successfully.
# 成功插入视频: 3-Betting in Poker: A Complete Guide for Beginners
# Video 45cTE7MVxJA metadata inserted successfully.
# 成功插入视频: You should never do this playing live poker! @razepoker3227 #poker #gamble #pokeronline
# Video a2Lk9HOQREw metadata inserted successfully.
# 成功插入视频: Phil Hellmuth gives valuable Poker Tips for Tournaments
# Video o10XmBZBl24 metadata inserted successfully.
# 成功插入视频: Why Run it Twice? (Poker Tips)
# Video nH3tvUchJJw metadata inserted successfully.
# 成功插入视频: How to Host the Perfect Poker Home Game - Live Poker Basics
# Video cLztHvZCgGg metadata inserted successfully.
# 成功插入视频: How To Win THOUSANDS Playing 2/5 - An ENTIRE Session Review |  Poker Vlog #93
# Video ysjzuZwvr-w metadata inserted successfully.
# 成功插入视频: Crazy Pineapple: Variation on Texas Holdem : Learn What Cards to Discard in Crazy Pineapple Poker
# Video CpSewSHZhmo metadata inserted successfully.
# 成功插入视频: How to Play Poker
# Video GXmTM3TH_J0 metadata inserted successfully.
# 成功插入视频: $50,000 Pot Limit Omaha High Roller FINAL TABLE!
# Video g0b9-DBwHBU metadata inserted successfully.
# 成功插入视频: Do Not EVER Do THIS at the Poker Table 😱 | Poker Tips For Beginners #shorts
# Video YedsbnVmjjM metadata inserted successfully.
# 成功插入视频: 7 Things NOT To Do When You&#39;re Playing A Poker Game
# Video qjQiFUKGTyE metadata inserted successfully.
# 成功插入视频: Poker Math You NEED to Know
# Video imd6UMx4dfI metadata inserted successfully.
# 成功插入视频: 10 BEGINNER Poker Tips I Wish I Knew When Starting
# Video Vj2SmNfSiBI metadata inserted successfully.
# 成功插入视频: Why Your Cards Don&#39;t Actually Matter At Small Stakes
# Video NYnDSUBkO5I metadata inserted successfully.
# 成功插入视频: Pot Control Lesson - Texas Holdem Poker Strategy - Hold em Poker Cash Game Coaching
# Video jEBDQUvBVb4 metadata inserted successfully.
# 成功插入视频: Poker Pro Reveals Common Sit and Go Mistakes (Online Poker Strategy)
# Video 3X006L6BNEc metadata inserted successfully.
# 成功插入视频: Reraising PREFLOP who will WIN $2,000???  - No Limit Texas Holdem Poker!!! #lasvegas #poker
# Video xfj6wFoFWsw metadata inserted successfully.
# 成功插入视频: 2 TIPS On When To BLUFF In Poker!
# 获取字幕失败:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=f9c4H2aARSM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Video f9c4H2aARSM metadata inserted successfully.
# 成功插入视频: TURBO Poker Tournaments 101 | SplitSuit Strategy
# Video mDIxpXMzDfU metadata inserted successfully.
# 成功插入视频: What&#39;s Wrong with No Limit Texas Hold &#39;Em According to Tom &quot;Durrrr&quot; Dwan
# Video _bf1cbv6rDc metadata inserted successfully.
# 成功插入视频: Texas Holdem: Poker Tournament Strategy : Play Hands Tight Early Poker Strategy in Texas Holdem
# Video _Bu-c_S8d-8 metadata inserted successfully.
# 成功插入视频: Top 3 Tips to Beat Your Poker Home Game
# Video s1lHUQb7bTE metadata inserted successfully.
# 成功插入视频: How to FOLD a GOOD POKER HAND - part 1 ♠️ How to play like a natural born poker player ♠️ PokerStars
# Video DXo7f21Ggi4 metadata inserted successfully.
# 成功插入视频: Learn strategies like THIS so you can beat 5/10 NL!  Poker Vlog #1. +$1,675
# Video _32aQ-A6Iw8 metadata inserted successfully.
# 成功插入视频: 10 Tips to Help You Win at Texas Hold &#39;em Poker.
# Video 3rl5DbSO-Y8 metadata inserted successfully.
# 成功插入视频: Quick Tips for Deep Stack Poker
# Video fEh2skuqKH0 metadata inserted successfully.
# 成功插入视频: BIG TROUBLE IN THE $2/5 GAME! // Poker Vlog 26
# Video IGQGBSof4jc metadata inserted successfully.
# 成功插入视频: How to Read Their Hand Every Time (Just Do This!)
# Video vAPlHla_e0I metadata inserted successfully.
# 成功插入视频: Poker- NL Holdem turbo Sit and Go strategy and tips -1 of 2
# Video 9l101Gg81o8 metadata inserted successfully.
# 成功插入视频: Chris Ferguson: Low Limit Strategy
# Video JV91VEjaMtw metadata inserted successfully.
# 成功插入视频: HOW to BEAT 1/2 Live Poker!!
# Video NkMy5PuKdvQ metadata inserted successfully.
# 成功插入视频: This Simple Flush Draw Strategy TRIPLED My Winnings
# Video LgfYfWZ5BoM metadata inserted successfully.
# 成功插入视频: When to Make a Deal in Poker Tournaments
# Video Y3-fkNpoLU8 metadata inserted successfully.
# 成功插入视频: Funniest Thing Yet #poker #pokerstars #texasholdem
# Video hhE__2QX9hQ metadata inserted successfully.
# 成功插入视频: The ADVANCED Pocket Pair Strategy (Used By Pros)
# Video 2KhlflDzEOE metadata inserted successfully.
# 成功插入视频: 1/2 Texas hold&#39;em poker have Ace King. Alarm bells go off when tight player starts betting into me
# Video WFOTNLrGyuE metadata inserted successfully.
# 成功插入视频: SHOULD I FOLD QUEENS PREFLOP? // No Limit Holdem Poker Vlog 15
# Video 3DivQGoH-OU metadata inserted successfully.
# 成功插入视频: 18 Questions Before Playing Live Poker
# 获取字幕失败:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=EDVK0FEdUgU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Video EDVK0FEdUgU metadata inserted successfully.
# 成功插入视频: Poker Night in America Texas Holdem&#39; Cash Game Episode Livestream 24/7
# 获取字幕失败:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=jCivzQgot7k! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Video jCivzQgot7k metadata inserted successfully.
# 成功插入视频: LIVE POKER | $5/$10/$25 No Limit Hold&#39;em Cash Game | TCHLIVE Dallas
# Video J1LodFZtAKM metadata inserted successfully.
# 成功插入视频: How To Play Pot Limit Omaha
# Video Hut-FscIaKE metadata inserted successfully.
# 成功插入视频: This Math Teacher Outplayed The Pros For 6-Figures! ♠️ PokerStars
# Video lgLFICHLOZA metadata inserted successfully.
# 成功插入视频: LADIES and the BLIND RAISE! in Las Vegas No Limit Texas Holdem #poker
# Video lmEQtXuEm7c metadata inserted successfully.
# 成功插入视频: Poker Final Table ESSENTIAL Pro Tip
# Video Pg6IwWAMeR8 metadata inserted successfully.
# 成功插入视频: How to Win at 6max Poker (Only Play These Cards!)
#
# 插入总结:
# 成功: 200
# 失败: 0
# (200, 0)

# %%
# 验证数据是否成功插入到 DynamoDB
def verify_dynamodb_insertion(table_name):
    """
    验证数据是否成功插入到 DynamoDB 表中
    :param table_name: DynamoDB 表名
    """
    table = dynamodb.Table(table_name)
    try:
        # 获取表中的所有项目
        response = table.scan()
        items = response['Items']
        
        print(f"\n=== DynamoDB 表 {table_name} 验证结果 ===")
        print(f"总记录数: {len(items)}")
        
        if items:
            print("\n示例记录:")
            print(json.dumps(items[0], indent=2, ensure_ascii=False))
            
            # 检查字段完整性
            fields = ['VideoID', 'Title', 'URL', 'Transcript']
            for field in fields:
                coverage = sum(1 for item in items if field in item)
                print(f"\n{field} 字段覆盖率: {coverage}/{len(items)}")
                
        return len(items)
    
    except ClientError as e:
        print(f"错误: {e.response['Error']['Message']}")
        return 0

# 执行验证
record_count = verify_dynamodb_insertion(table_name)
# Out:
# === DynamoDB 表 youtube_poker_db 验证结果 ===
# 总记录数: 10
#
# 示例记录:
# {
#   "Title": "9 TEXAS HOLD&#39;EM Poker Tips For Beginners (Just Do This!)",
#   "Transcript": "[{\"text\": \"what's going on guys Nathan here and\", \"start\": 0.0, \"duration\": 3.3}, {\"text\": \"today I'm going to give you the top nine\", \"start\": 1.8, \"duration\": 4.14}, {\"text\": \"things that you will never see a good\", \"start\": 3.3, \"duration\": 5.28}, {\"text\": \"Texas Hold'em poker player doing let's\", \"start\": 5.94, \"duration\": 4.44}, {\"text\": \"jump right into it all right guys so in\", \"start\": 8.58, \"duration\": 4.08}, {\"text\": \"my 10 plus years as a professional in\", \"start\": 10.38, \"duration\": 4.139}, {\"text\": \"this game I can tell you that I have\", \"start\": 12.66, \"duration\": 4.619}, {\"text\": \"never seen a good Texas poker player\", \"start\": 14.519, \"duration\": 5.281}, {\"text\": \"doing any of the nine things on this\", \"start\": 17.279, \"duration\": 4.561}, {\"text\": \"list if you see somebody doing one of\", \"start\": 19.8, \"duration\": 3.72}, {\"text\": \"these things you're probably in a good\", \"start\": 21.84, \"duration\": 4.199}, {\"text\": \"poker game AKA you're in a game with\", \"start\": 23.52, \"duration\": 4.2}, {\"text\": \"some fish in it the people we make the\", \"start\": 26.039, \"duration\": 3.601}, {\"text\": \"money against so counting down from nine\", \"start\": 27.72, \"duration\": 4.08}, {\"text\": \"to one here we go number nine is\", \"start\": 29.64, \"duration\": 4.919}, {\"text\": \"re-raising with Ace King especially when\", \"start\": 31.8, \"duration\": 4.56}, {\"text\": \"you hit the top pair on the Flop I'm\", \"start\": 34.559, \"duration\": 3.901}, {\"text\": \"going to give you an example right now\", \"start\": 36.36, \"duration\": 4.14}, {\"text\": \"just to show you exactly what I'm\", \"start\": 38.46, \"duration\": 3.72}, {\"text\": \"talking about so you raise up the old\", \"start\": 40.5, \"duration\": 3.78}, {\"text\": \"days King Ace of Hearts King of Spades\", \"start\": 42.18, \"duration\": 3.96}, {\"text\": \"and the Flop comes down with a Queen of\", \"start\": 44.28, \"duration\": 4.38}, {\"text\": \"Spades King of Clubs and jack of\", \"start\": 46.14, \"duration\": 4.259}, {\"text\": \"diamonds so a lot of beginner and\", \"start\": 48.66, \"duration\": 3.899}, {\"text\": \"amateur poker players are like wow this\", \"start\": 50.399, \"duration\": 4.921}, {\"text\": \"is amazing right we got top pair I got\", \"start\": 52.559, \"duration\": 5.101}, {\"text\": \"the top kicker with the ace I even got a\", \"start\": 55.32, \"duration\": 4.7}, {\"text\": \"straight drop a 10 comes but guys savvy\", \"start\": 57.66, \"duration\": 4.8}, {\"text\": \"experienced Texas Holdem players know\", \"start\": 60.02, \"duration\": 5.02}, {\"text\": \"that this is a dangerous board they know\", \"start\": 62.46, \"duration\": 5.22}, {\"text\": \"how to read board textures this is\", \"start\": 65.04, \"duration\": 4.259}, {\"text\": \"something that I talk about a lot in\", \"start\": 67.68, \"duration\": 3.6}, {\"text\": \"these videos here on the channel is\", \"start\": 69.299, \"duration\": 4.261}, {\"text\": \"understanding dangerous flops like this\", \"start\": 71.28, \"duration\": 5.82}, {\"text\": \"one and harmless flops such as a king\", \"start\": 73.56, \"duration\": 6.419}, {\"text\": \"seven Deuce totally different plot from\", \"start\": 77.1, \"duration\": 4.559}, {\"text\": \"this one so guys if you're up against\", \"start\": 79.979, \"duration\": 3.541}, {\"text\": \"any kind of decent normal thinking\", \"start\": 81.659, \"duration\": 3.541}, {\"text\": \"opponent who's watching videos like this\", \"start\": 83.52, \"duration\": 4.56}, {\"text\": \"they make a bet you should be just flat\", \"start\": 85.2, \"duration\": 5.16}, {\"text\": \"calling in this situation you do not\", \"start\": 88.08, \"duration\": 4.38}, {\"text\": \"want to be raising and let me explain\", \"start\": 90.36, \"duration\": 4.259}, {\"text\": \"why right now guys the problem with\", \"start\": ...
#   "VideoID": "noKz7aCfwNM",
#   "URL": "https://www.youtube.com/watch?v=noKz7aCfwNM"
# }
#
# VideoID 字段覆盖率: 10/10
#
# Title 字段覆盖率: 10/10
#
# URL 字段覆盖率: 10/10
#
# Transcript 字段覆盖率: 10/10
