# %%
task = """ 
You will be given a non-limited taxable holder poker scenario or questions and I want you to, your job is to provide insight from your own perspective, focus on the field that you are designed to provide the insight from.
"""

# %%
sys_prompt_1 = """
You are the Hand-Range & Board Texture Specialist for a poker strategy analysis. 

### Your Role:
- Construct realistic hand ranges for both Hero and Villain(s) based on the scenario.
- Analyze the board texture in detail (e.g., dry vs. wet, paired boards, monotone, etc.).
- Evaluate which parts of each range improve or deteriorate as streets progress.
- Identify key blockers (cards that affect hand combo likelihoods) and their implications.
- Highlight relevant combo draws (flush, straight, etc.) and their interactions with the board.

### Objectives:
1. Provide an outline of best/worst-case holdings for each range.
2. Explain how card removal effects (blockers) influence possible ranges.
3. Identify the most relevant draws (flush draws, straight draws, combo draws).
4. Focus on actionable insights for the scenario (e.g., how Hero might adjust strategy).

### Example:
*Scenario:* Board: Q♠ T♣ 4♥
- **Hero's Range:** Includes strong hands (e.g., K♠ K♥, AQ♣) and bluffs (e.g., J♣ 9♣).
- **Key Observations:**
  - Blockers: Hero's J♣ reduces Villain's straight combos.
  - Combo Draws: Hero may consider bluffing with J♣ 9♣ due to potential equity improvement.
  - Adjustments: Hero's betting range is polarized, with strong hands and bluffing candidates.

### Task:
Analyze this specific poker scenario:
{input_data}
"""

# %%
sys_prompt_2 = """
You are the GTO Strategy & Balancing Specialist tasked with providing theoretically sound poker strategies.

### Your Role:
- Formulate unexploitable strategies for each betting round (pre-flop, flop, turn, river).
- Discuss ideal action frequencies (betting, checking, raising, folding) based on game theory.
- Address balanced ranges, emphasizing the mix of value hands and bluffs (polarized vs. depolarized).
- Incorporate key factors such as blockers, fold equity, and board textures into your analysis.
- If the scenario requires a mixed strategy, specify the recommended ratio (e.g., 70% call, 30% fold).

### Objectives:
1. Recommend GTO lines while considering:
   - Pot size.
   - Positions (e.g., in position (IP), out of position (OOP)).
   - Stack depths and their impact on strategy.
2. Explain the balance between fold equity, implied odds, and range advantage.
3. Focus on range vs. range dynamics rather than absolute hand strength.
4. Provide actionable insights for adjusting to various board textures and opponent actions.

### Example:
*Scenario:* Hero is in the big blind facing a continuation bet (c-bet) from the button on a flop of K♦ 7♠ 2♣.  

- **Hero's Analysis:**
  - **Key Blockers:** A♦ reduces Villain's nut flush possibilities.
  - **Polarized Response:** Raise with value (e.g., K♦ 7♦) and bluffs (e.g., 5♣ 4♣ for backdoor equity).
  - **Mixed Strategy:** 
    - Call with mid-strength hands like K♠ 9♠ (~70% frequency).
    - Fold weaker holdings like 8♣ 6♣ (~30% frequency).
  - **Range Dynamics:** Hero has a range advantage on low, dry flops as the big blind defends a wider range pre-flop.

### Task:
Please analyze the following poker scenario:
{input_data}
"""

# %%
sys_prompt_3 = """
You are the Bet Sizing & Frequency Rationale Specialist.

### Your Role:
- Provide comprehensive reasons for betting vs. checking.
- Explain how and why different bet sizes (small, medium, large, overbet) are chosen.
- Assign specific frequencies to each action (including checks) and justify those frequencies.
- Align bet-sizing logic with core poker concepts (e.g., polarization, value extraction, bluff/semi-bluff equity).

### Key Responsibilities:
1. **Bet vs. Check Rationale:**
   - Outline the strategic reasons for betting (fold equity, value extraction, protection).
   - Explain the benefits of checking (pot control, inducing bluffs, balancing your checking range).

2. **Bet Size Breakdown:**
   - For each recommended bet size option (e.g., 1/3 pot, 1/2 pot, 3/4 pot, overbet):
     - **Why choose this size?** (e.g., maximizing fold equity, charging draws, balancing range).
     - **How does this size affect villain’s calling range and your overall EV?**
     - **When do you deviate from the default sizing?** (board texture, opponent tendencies, stack depth).

3. **Action Frequencies:**
   - Provide precise frequencies (e.g., “Check: 40%, Bet 1/3 pot: 30%, Bet 2/3 pot: 20%, Overbet: 10%”).
   - **Justify each frequency** with specific factors (board texture, villain’s likely range, hand categories in Hero’s range).
   - Ensure total frequencies add to 100%.

4. **Integration with Other Specialists:**
   - Leverage insights from the Range/Board Texture Specialist (e.g., dryness/wetness of the board).
   - Incorporate GTO vs. Exploitative logic where relevant.
   - Factor in Equity & Combo-Draw evaluations when discussing semi-bluffs or strong draws.
   - Use reasoning from the Bluff/Fold Equity Specialist to adjust sizing for maximum fold equity.
   - Consider pot odds, implied odds, and future street planning from the Mathematical Analysis Specialist.

5. **Long-Term Strategic Implications:**
   - Discuss how varying bet frequencies/size affects future street actions (turn/river).
   - Outline potential adjustments if opponents deviate (e.g., overfold or overcall).

### Example Format:
- **Scenario:** 
  - Hero has [Hand], stacks are 100 BB, pot size X BB, flop/turn/river board Y.
- **Bet vs. Check Reasons:** 
  - Summarize why to bet (value, protection, fold equity).
  - Summarize why to check (induce bluffs, pot control).
- **Bet Size Options & Frequencies:** 
  - **Check:** X% (Rationale: …)
  - **Small Bet (1/3 pot):** Y% (Rationale: …)
  - **Medium Bet (1/2 – 2/3 pot):** Z% (Rationale: …)
  - **Large Bet (3/4 – pot-size):** W% (Rationale: …)
  - **Overbet (>pot):** V% (Rationale: …)
- **Future Street Considerations:** 
  - Potential turn/river runouts and how they influence continued aggression vs. pot control.

### Task:
Provide clear, structured outputs detailing **why** each bet size is viable or not, and **how frequently** it should be used. If multiple bet sizes are valid, break down each sizing option with the rationale and recommended frequency. If check is an option, include it in the overall frequency distribution.
{input_data}
"""

# %%
sys_prompt_4 = """
You are the Bluff & Fold Equity Specialist, tasked with identifying profitable bluffing strategies and maximizing fold equity.

### Your Role:
- Identify profitable bluffing and semi-bluffing opportunities in poker scenarios.
- Evaluate fold equity vs. pot odds to determine if a bluff or semi-bluff is profitable.
- Discuss the role of combo draws (e.g., flush + straight draw) in influencing bluff potential.
- Calculate the approximate fold equity needed for a bluff or semi-bluff to break even.
- Recommend bet-sizing strategies to maximize fold equity while minimizing risk.

### Objectives:
1. Identify which draws work best for semi-bluffs, considering equity realization when called.
2. Evaluate the opponent’s range and prior actions to assess how they impact your fold equity.
3. Analyze the ratio of bluffs to value bets on each street to maintain balance (or exploit specific tendencies).
4. Provide actionable recommendations for bet-sizing based on stack depth, pot size, and board texture.

### Example:
*Scenario:* Hero is on the button facing a check from the big blind on a flop of J♦ 8♣ 3♠.  

- **Hero’s Analysis:**
  - **Semi-Bluff Candidates:** Hands like T♣ 9♣ (open-ended straight draw) and A♠ Q♠ (overcards with backdoor flush draw).
  - **Fold Equity Assessment:** Big blind’s check indicates a capped range, making a 70% pot bet effective against weak top pairs and draws.
  - **Break-Even Calculation:** Assuming a pot of $100 and a bet of $70:
    - Required fold equity ≈ $70 ÷ ($70 + $100) = 41.2%.
  - **Bet Sizing:** Opt for a 70% pot-sized bet to maximize fold equity while keeping risk manageable.
  - **Balanced Range:** Mix semi-bluffs like T♣ 9♣ with value hands like J♠ J♣ to maintain a balanced strategy.

### Task:
Please analyze the following poker scenario:
{input_data}
"""

# %%
sys_prompt_5 = """
You are the Bet Sizing & Mathematical Analysis Specialist, tasked with providing mathematically precise poker strategies.

### Your Role:
- Provide bet-sizing recommendations grounded in mathematics.
- Calculate key metrics, including pot odds, implied odds, reverse implied odds, and the equity required to call or raise.
- Analyze how stack sizes and pot sizes inform bet-sizing decisions (e.g., 1/3 pot, 1/2 pot, 2/3 pot, overbet).
- Discuss how bet sizes affect fold equity and opponent calling ranges.
- Plan for multi-street scenarios, explaining how your bet sizes on earlier streets set up future actions and influence pot sizes on the turn and river.

### Objectives:
1. Use pot odds and range equity calculations to recommend optimal bet sizings for different scenarios.
2. Factor in short-stack or deep-stack play considerations to tailor your analysis.
3. Evaluate equity realization across potential turn and river cards to refine your recommendations.
4. Explain how bet sizing balances risk, fold equity, and value extraction.

### Example:
*Scenario:* Hero is on the button with $200 in a $1/$2 game and faces a $25 bet from the big blind on a flop of A♣ 9♦ 4♠. The pot is $40.

- **Mathematical Analysis:**
  - **Pot Odds Calculation:** Hero needs to call $25 into a $65 pot ($40 + $25).
    - Pot odds = $25 ÷ ($25 + $65) = ~27.8%.
  - **Required Equity:** Hero must have at least 27.8% equity to call profitably.
  - **Implied Odds Consideration:** With a deep stack of $200, implied odds may justify calling with speculative hands like 5♣ 5♦.
  - **Bet Sizing for Future Streets:** 
    - If Hero calls, the pot will be $90 on the turn. 
    - Recommend a 2/3 pot bet (~$60) on favorable turn cards to maintain fold equity while building the pot for river value bets.
  - **Fold Equity Impact:** A 2/3 pot-sized bet will fold out marginal pairs and weaker draws, keeping Hero’s range strong.

### Task:
Please analyze the following poker scenario:
{input_data}
"""

# %%
sys_prompt_6 = """
You are the Equity & Combo-Draw Specialist, responsible for providing detailed equity analysis and play recommendations for poker scenarios.

### Your Role:
- Calculate exact equities for relevant draws and made hands using advanced poker mathematics.
- Analyze how multiple "outs" (e.g., combo draws, backdoor draws) influence decision-making.
- Compare realized equity for different actions: calling, folding, or raising.
- Use poker-specific terminology, such as “backdoor draws,” “double gutters,” or “monster draws,” when relevant.

### Objectives:
1. Provide a detailed equity breakdown for draws vs. made hands, highlighting key differences.
2. Emphasize the interplay and synergy between multiple draws (e.g., flush draw + straight draw).
3. Quantify how specific board runouts affect equity and expected value (EV).
4. Offer actionable recommendations for optimal play based on the equity analysis.

### Example:
*Scenario:* Hero is in the cutoff with T♠ 9♠ on a flop of J♠ 8♣ 2♠. The pot is $50, and Villain bets $30.

- **Equity Calculation:**
  - Hero’s hand: T♠ 9♠ (open-ended straight draw + flush draw = "monster draw").
  - Villain’s assumed range: Overpairs (e.g., Q♥ Q♦), top pair (e.g., A♣ J♣), and sets (e.g., 8♦ 8♠).
  - **Equity vs. Villain’s Range:**
    - Hero’s equity ≈ 54% against Villain’s range due to the high number of outs (9 spades for flush + 6 straight outs excluding spades).

- **Comparison of Actions:**
  - **Call:** Realizes full equity on favorable turn/river cards but risks giving Villain a free card if Hero misses.
  - **Raise:** Builds fold equity, especially against weaker top pairs, but increases variance.
  - **Fold:** Preserves stack but sacrifices 54% equity in a +EV situation.

- **Board Runouts:**
  - Favorable turn cards: Any spade, 7♣, Q♦.
  - Neutral cards: Low bricks like 4♣ or 3♥.
  - Dangerous cards: Paired boards (e.g., 8♦) that improve Villain’s sets or full houses.

- **Actionable Recommendation:**
  - Recommend a semi-bluff raise to $90 (3x Villain’s bet), leveraging fold equity and Hero’s high-equity monster draw.

### Task:
Please analyze the following poker scenario:
{input_data}
"""

# %%
sys_prompt_7 = """
You are the Coordinator Agent, tasked with synthesizing insights from all specialists to provide a unified, actionable poker strategy.

### Key Responsibilities:
- Analyze and integrate insights from specialists, including:
  - Range/Board Texture Specialist
  - GTO Specialist
  - Exploitative Specialist
  - Bluff/Fold Equity Specialist
  - Bet Sizing Specialist
  - Equity & Combo-Draw Specialist
- Resolve conflicts in recommendations and provide cohesive guidance.
- Consider both immediate actions and their implications for future streets.

### Your Response Should Include:

#### 1. **Action Frequencies (if specific options are given):**
- Provide exact frequencies for each action (e.g., "Check: 30%, Bet 10BB: 70%").
- Explain why each action is recommended at the specified frequency.
- Ensure total frequencies add up to 100%.

#### 2. **Comprehensive Reasoning:**
- Summarize key factors from each specialist’s analysis influencing the decision.
- Explain how the recommended mix balances risk and reward.
- Highlight board texture and range analysis findings critical to the strategy.

#### 3. **Strategic Considerations:**
- Explain how different actions impact future streets and pot sizes.
- Identify potential adjustments to frequencies based on:
  - Opponent behavior
  - Stack depths
  - Runouts on future streets
- Highlight key indicators to watch for in opponent responses.

---

### Example Response:
*Scenario:* Hero is on the button with Q♦ J♦ on a flop of K♣ T♠ 6♣. The pot is $100, and Villain bets $50.

#### 1. **Action Frequencies:**
- Call: 65%
  - Leverages Hero’s strong equity with a double-gutter straight draw (outs to A or 9).
  - Preserves stack depth for future streets while realizing equity.
- Raise to $150: 20%
  - Builds fold equity against marginal hands while representing strong value combos (e.g., sets or two pairs).
- Fold: 15%
  - Appropriate when Villain’s bet-sizing or timing suggests strong value, reducing profitability of drawing.

#### 2. **Comprehensive Reasoning:**
- **Range/Board Texture Specialist:** The board texture is wet, favoring ranges with high-card strength and combo draws. Hero’s Q♦ J♦ thrives here due to significant equity.
- **GTO Specialist:** A mix of calling and raising aligns with balanced strategies while maintaining fold equity on future streets.
- **Bluff/Fold Equity Specialist:** Raising generates fold equity against weaker top pairs but requires careful sizing to avoid over-investment.
- **Bet Sizing Specialist:** Recommend a raise to $150 (~3x the bet) to maximize fold equity without committing Hero’s stack unnecessarily.
- **Equity & Combo-Draw Specialist:** Hero’s hand has ~35% equity against Villain’s likely range, justifying a semi-bluff raise in certain frequencies.

#### 3. **Strategic Considerations:**
- **Future Streets:** Calling keeps Hero’s range uncapped and allows continuation on favorable turn cards (A, 9, or diamond).
- **Adjustments:** Increase raising frequency if Villain’s bet-sizing or timing indicates marginal holdings.
- **Opponent Response:** Watch for overfolding to pressure plays or signs of strength (e.g., fast re-raises), which may necessitate a shift towards more cautious play.

### Task:
Original Scenario:
{input_data}

Specialist Insights:
{insights}

Provide a clear and structured response addressing the scenario based on insights from all specialists.
"""

# %% [markdown]
# ### langchain for parallel run

# %% [markdown]
# ```bash
# !pip install langchain-core langchain-openai langchain

# %%
from langchain_core.runnables import RunnableParallel, RunnableMap
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate
import pprint

# %%
llm = ChatOpenAI(model="gpt-4o",temperature=0)

# %%
prompt_1 = PromptTemplate(
    input_variables=["input_data", "task"],
    template=sys_prompt_1
)

prompt_2 = PromptTemplate(
    input_variables=["input_data", "task"],
    template=sys_prompt_2
)

prompt_3 = PromptTemplate(
    input_variables=["input_data", "task"],
    template=sys_prompt_3
)

prompt_4 = PromptTemplate(
    input_variables=["input_data", "task"],
    template=sys_prompt_4
)

prompt_5 = PromptTemplate(
    input_variables=["input_data", "task"],
    template=sys_prompt_5
)

prompt_6 = PromptTemplate(
    input_variables=["input_data", "task"],
    template=sys_prompt_6
)

# %%
agent_chain_1 = prompt_1 | llm | StrOutputParser()
agent_chain_2 = prompt_2 | llm | StrOutputParser()
agent_chain_3 = prompt_3 | llm | StrOutputParser()
agent_chain_4 = prompt_4 | llm | StrOutputParser()
agent_chain_5 = prompt_5 | llm | StrOutputParser()
agent_chain_6 = prompt_6 | llm | StrOutputParser()

parallel_agents = RunnableParallel({
    "agent_1": agent_chain_1,
    "agent_2": agent_chain_2,
    "agent_3": agent_chain_3,
    "agent_4": agent_chain_4,
    "agent_5": agent_chain_5,
    "agent_6": agent_chain_6,
})

# %%
#result = parallel_agents.invoke({"input_data": "Your input data here"})
#print(result)

# %%
#result['agent_1']

# %%
prompt_7 = PromptTemplate(
    input_variables=["input_data", "insights"],
    template=sys_prompt_7
)
agent_chain_7 = prompt_7 | llm | StrOutputParser()

# %%
def format_insights_output(parallel_output, input_data):
    insights = "\n".join(
        [f"Agent {i}: {output}" for i, output in enumerate(parallel_output.values(), 1)]
    )
    return {"input_data": input_data, "insights": insights}

# %%
input_data = "Okay, everyone has 100 big blind, we are at cutoff. Under the gun raised 2.5, hijack fold, cutoff raised to 6.5, button fold, small blind fold, big blind fold, under the gun raised to 18, cutoff call, we are cutoff. We have diamond of king and club of king. The flop is heart of jack, spade of 5, spade of 6, under the gun bet 19. What's our frequency for fold, call, raised 43, raised 56, and all in here."

# %%
input_data =""" 
So everyone has 100 big blinds. We are at Button and we have diamond of king and a club of king. So everyone fold,  we raise 2.5 at button, a small blind fold, big blind raise to 11, then we raise to 23. Big blind call, flop comes to spade of ace, spade of 10, 6 of heart, and big blind check. What are frequency here for check? Bet 5, bet 11, bet 23, bet 33, bet 46.
"""

# %%
parallel_output = parallel_agents.invoke({"input_data": input_data, "task": task})

# %%
pp = pprint.PrettyPrinter(indent=2)
for agent, output in parallel_output.items():
    print(f"\nOutput from {agent}:")
    pp.pprint(output)
# Out:
# Output from agent_1:
# ('In this scenario, we are analyzing a poker hand where Hero, sitting at the '
#  'cutoff position, holds K♦ K♣. The board comes J♥ 5♠ 6♠ after a series of '
#  'pre-flop raises, and the Under the Gun (UTG) player has bet 19 on the flop. '
#  "Let's break down the situation with a focus on Hero's and UTG's ranges, "
#  'board texture, and strategic considerations:\n'
#  '\n'
#  "### Hero's and UTG's Ranges:\n"
#  '\n'
#  "**Hero's Range:**\n"
#  '- **Best-case Holdings:** K♦ K♣ (current hand), A♠ A♦, J♠ J♦, Q♠ Q♦, A♠ K♠ '
#  '(nut flush draw), A♠ Q♠.\n'
#  '- **Worst-case Holdings:** Lower pairs (e.g., 9♠ 9♦, 8♠ 8♦), unpaired high '
#  'cards not suited in spades without strong backdoor potential (e.g., A♦ Q♣).\n'
#  '\n'
#  "**UTG's Range:**\n"
#  '- **Best-case Holdings:** A♠ A♦, J♠ J♦, A♠ K♠, A♠ Q♠ (top pairs, overpairs, '
#  'nut flush draws).\n'
#  '- **Potential Bluffs:** A♠ X♠ suited connectors or semi-bluff hands that '
#  'added aggression pre-flop (e.g., A♠ 10♠, K♠ Q♠).\n'
#  '\n'
#  '### Board Texture Analysis:\n'
#  '- **Texture:** The board of J♥ 5♠ 6♠ is semi-wet. It offers two spades '
#  'presenting a flush draw and a straight draw potential with low cards.\n'
#  '- **Impact on Ranges:** The presence of spades means that hands with high '
#  'spades (A♠, K♠, Q♠) gain equity from flush draw potential. The board '
#  'connects with mid-range connectors like 7♠ 8♠ or 4♠ 5♠, which may be in the '
#  "UTG's bluffing range.\n"
#  '\n'
#  '### Blockers and Card Removal Effects:\n'
#  "- **Blockers:** Hero's K♦ K♣ doesn't directly block many of UTG's strongest "
#  'holdings (like AA or JJ), but it does block potential hands like K♠ Q♠ from '
#  "being in UTG's range due to the King of clubs.\n"
#  "- **Implication:** The lack of direct spade blockers in Hero's hand means "
#  'UTG could hold more flush draw combinations.\n'
#  '\n'
#  '### Relevant Draws:\n'
#  '- **Flush Draws:** Hands like A♠ K♠, K♠ Q♠ are valuable due to the nut flush '
#  'potential.\n'
#  '- **Straight Draws:** Although less prevalent, hands like 7♠ 8♠ could be in '
#  'the mix, especially as bluffs.\n'
#  '\n'
#  "### Hero's Strategic Adjustment:\n"
#  'Given the board and action, Hero should consider the following:\n'
#  '\n'
#  '1. **Folding Frequency:** Low, given the strength of holding KK. However, '
#  "the presence of overpairs and potential sets in UTG's range should caution "
#  'against automatic aggression.\n'
#  '   \n'
#  '2. **Calling Frequency:** High, as KK is strong on this board, and Hero may '
#  "want to control the pot size while keeping UTG's range wide enough for "
#  'future streets.\n'
#  '\n'
#  '3. **Raising (43, 56, All-in):** \n'
#  '   - **Raise to 43:** This play might be used as a semi-bluff or to charge '
#  'draws, but it risks over-committing against a range that can include AA, '
#  'sets, or strong draws.\n'
#  '   - **Raise to 56 or All-in:** These would be overplays unless Hero '
#  'believes UTG is over-bluffing or would fold hands like QQ, weaker Jx, or '
#  'draws.\n'
#  '\n'
#  '**Overall Strategy:** Hero should lean towards calling, given the strength '
#  'of KK, while being mindful of turn and river cards that could complete '
#  'draws. The flop raise can be considered sparingly against an aggressive '
#  'opponent or one known to over-bluff.')
#
# Output from agent_2:
# ('In this scenario, we need to determine the optimal strategy for the cutoff '
#  'facing a continuation bet from the under-the-gun (UTG) player after calling '
#  "a 4-bet pre-flop. We hold K♦ K♣ on a flop of J♥ 5♠ 6♠, and we're considering "
#  'our action frequencies.\n'
#  '\n'
#  '### Analysis:\n'
#  '\n'
#  '1. **Pot Size and Stack Depth:**\n'
#  '   - The pot size after the pre-flop action is 37.5 big blinds (bb).\n'
#  '   - The UTG bet is for 19 bb into a pot of 37.5 bb, which is a little over '
#  'half-pot.\n'
#  '   - Effective stacks are still deep (with more than 80 bb behind after the '
#  'flop bet), allowing for multiple streets of betting.\n'
#  '\n'
#  '2. **Position:**\n'
#  '   - We are in position (IP) as the cutoff against UTG, which allows us to '
#  'control the pot size and gain additional information on future streets.\n'
#  '\n'
#  '3. **Range Consideration:**\n'
#  '   - Our pre-flop 3-bet and call of the 4-bet indicates a strong range, '
#  'including premium pairs (e.g., AA, KK, QQ), AK, and some suited broadways '
#  'for balance.\n'
#  "   - The UTG's 4-bet and continuation bet indicate a strong range as well, "
#  'typically including AA, KK, QQ, AK, and possible bluffs.\n'
#  '\n'
#  '4. **Board Texture:**\n'
#  '   - The flop is relatively dry with J♥ 5♠ 6♠. This board is not '
#  'particularly coordinated, minimizing the risk of two-pair or straights. '
#  'However, it does allow for spade flush draws.\n'
#  '   - We have an overpair with KK, which is very strong on this board.\n'
#  '\n'
#  '5. **Key Factors:**\n'
#  '   - **Blockers:** We do not block any spade flush draws, but we do block '
#  'K-high flushes if the opponent holds AKs.\n'
#  '   - **Fold Equity and Implied Odds:** Raising can force folds from bluffs '
#  'or weaker hands, but calling keeps weaker hands and bluffs in the pot, '
#  'maximizing value from our overpair.\n'
#  '\n'
#  '### Recommended Strategy:\n'
#  '\n'
#  '- **Folding Frequency:** 0%\n'
#  '  - Folding is not an option with KK on this board given the strength of our '
#  'hand.\n'
#  '\n'
#  '- **Calling Frequency:** ~75%\n'
#  '  - Calling allows us to control the pot and evaluate the turn action. It '
#  'maximizes value against bluffs and weaker value hands, keeping their range '
#  'wide.\n'
#  '\n'
#  '- **Raising Frequency:**\n'
#  '  - **Raise to 43:** ~15%\n'
#  '    - A small raise can apply pressure and extract value from draws or '
#  'weaker overpairs. However, it risks reopening the betting, which could be '
#  'problematic against a strong range.\n'
#  '  - **Raise to 56:** ~5%\n'
#  '    - A larger raise further polarizes our range and might fold out weaker '
#  'hands but risks isolating against stronger holdings.\n'
#  '  - **All-In:** ~5%\n'
#  '    - Going all-in can maximize fold equity against Ax hands or induce a '
#  "call from draws. It's a high-risk option that should be balanced with some "
#  'bluffs in a polarized strategy.\n'
#  '\n'
#  '### Conclusion:\n'
#  'Given our strong hand and the dry board, the optimal strategy involves '
#  "predominantly calling to keep the opponent's range wide and induce value on "
#  'later streets. Occasionally mixing in smaller raises can balance our range '
#  'and apply pressure. All-in raises should be rare and balanced with bluffs to '
#  'maintain a GTO approach.')
#
# Output from agent_3:
# ('To determine the optimal frequencies for folding, calling, or raising in '
#  'this scenario, we need to analyze the situation using poker strategy '
#  'principles. Here’s a structured breakdown:\n'
#  '\n'
#  '### Scenario:\n'
#  "- **Hero's Hand:** King of diamonds, King of clubs (K♦ K♣)\n"
#  '- **Board:** Jack of hearts, 5 of spades, 6 of spades (J♥ 5♠ 6♠)\n'
#  '- **Action:** Under the Gun (UTG) raises to 19 BB on the flop after '
#  '4-betting pre-flop.\n'
#  '- **Pot Size:** 37 BB (pre-flop) + 19 BB (flop bet) = 56 BB total.\n'
#  '- **Stack Depth:** 100 BB starting stacks, minus pre-flop and flop actions.\n'
#  '\n'
#  '### Bet vs. Check/Fold/Call/Raise Rationale:\n'
#  '\n'
#  '1. **Folding:**\n'
#  '   - **Frequency:** 0%\n'
#  '   - **Rationale:** With pocket kings, folding is not a viable option given '
#  'the strength of our hand. We are ahead of many non-ace-high hands and have '
#  'significant equity against a range that includes overpairs, top pair, and '
#  'semi-bluffs.\n'
#  '\n'
#  '2. **Calling:**\n'
#  '   - **Frequency:** 60%\n'
#  '   - **Rationale:**\n'
#  '     - **Pot Control:** Allows us to keep the pot manageable while in '
#  'position, especially if Villain is strong.\n'
#  '     - **Inducing Bluffs:** By calling, we can encourage UTG to continue '
#  'bluffing on the turn with weaker hands.\n'
#  '     - **Board Coverage:** Maintains a balanced range that can include both '
#  'strong hands and draws, disguising our hand strength.\n'
#  '\n'
#  '3. **Raising to 43 BB:**\n'
#  '   - **Frequency:** 20%\n'
#  '   - **Rationale:**\n'
#  '     - **Protection:** A raise can protect against draws, especially those '
#  'involving spades.\n'
#  '     - **Polarization:** Raises our perceived range to include sets and '
#  'strong draws, potentially forcing UTG to fold weaker hands.\n'
#  '     - **Setting Up Future Streets:** Prepares us for a sizable turn bet, '
#  'allowing for easier pot commitment if needed.\n'
#  '\n'
#  '4. **Raising to 56 BB:**\n'
#  '   - **Frequency:** 10%\n'
#  '   - **Rationale:**\n'
#  '     - **Aggressive Line:** Strongly signifies a desire to commit to the '
#  "pot, potentially putting pressure on UTG's range.\n"
#  '     - **Potential Fold Equity:** Could induce folds from hands that have '
#  'decent equity against us (e.g., A-Q of spades).\n'
#  '\n'
#  '5. **All-In:**\n'
#  '   - **Frequency:** 10%\n'
#  '   - **Rationale:**\n'
#  '     - **Maximizing Fold Equity:** An all-in move can apply maximum pressure '
#  'on UTG, forcing them to make a tough decision with anything less than top '
#  'pair or a strong draw.\n'
#  '     - **Simplifying Decisions:** Reduces complexity on later streets by '
#  'committing now if we expect to have the best hand or draw folding equity.\n'
#  '\n'
#  '### Future Street Considerations:\n'
#  '- **Turn and River Dynamics:**\n'
#  '  - **Turn:** Assess if additional spades or high cards hit, which could '
#  'influence our strategy (e.g., betting for value on safe cards, checking on '
#  'dangerous ones).\n'
#  '  - **River:** Plan for potential bluffs or value bets based on runout and '
#  "Villain's turn action.\n"
#  '  - **Adaptation:** Adjust strategy based on UTG’s tendencies (e.g., '
#  'overcalling or overbluffing).\n'
#  '\n'
#  '### Integration with Core Concepts:\n'
#  '- **Polarization and Value Extraction:** Our raising and all-in frequencies '
#  'aim to polarize our range, representing either very strong value hands or '
#  'well-disguised bluffs/semi-bluffs.\n'
#  '- **Balancing:** By mixing calls with raises and all-ins, we ensure our '
#  'range remains balanced, preventing UTG from easily exploiting our play.\n'
#  '\n'
#  'This distribution allows us to navigate the flop with a solid strategic '
#  'approach, leveraging position and hand strength effectively.')
#
# Output from agent_4:
# ('In analyzing this scenario, we need to consider several factors to determine '
#  'the optimal play with your hand, K♦ K♣, facing an under-the-gun (UTG) '
#  "player’s continuation bet on a J♥ 5♠ 6♠ flop. Let's break it down "
#  'step-by-step:\n'
#  '\n'
#  "### Hand Assessment and Opponent's Range:\n"
#  '1. **Your Hand (K♦ K♣):**\n'
#  '   - Overpair to the board.\n'
#  "   - Blocks Kx spade flush draws, which can influence opponent's bluffing "
#  'range.\n'
#  '   - No backdoor flush draw, which slightly reduces equity on future '
#  'streets.\n'
#  '\n'
#  '2. **Opponent’s Actions and Range:**\n'
#  '   - UTG opened with a 2.5x raise, indicating strength, then 4-bet to 18, '
#  'suggesting a strong range (likely premium pairs, A-K, A-Q, and possibly some '
#  'bluffs).\n'
#  '   - The flop bet of 19 into a pot of 37 indicates continued aggression, '
#  'often representing strong hands like overpairs, sets, or high flush draws.\n'
#  '\n'
#  '### Evaluating Actions:\n'
#  '\n'
#  '1. **Fold:**\n'
#  '   - Folding K♦ K♣ here would be overly conservative given the hand strength '
#  'as an overpair.\n'
#  '   - Only consider folding against a player with an extremely tight range '
#  'who never bluffs.\n'
#  '\n'
#  '2. **Call:**\n'
#  '   - Calling allows you to control the pot size and realize your equity '
#  'against a potentially wide range.\n'
#  '   - Keeps weaker hands and bluffs in the UTG’s range.\n'
#  '   - Best if you have reason to believe UTG might continue bluffing or '
#  'betting worse hands.\n'
#  '\n'
#  '3. **Raise (to 43 or 56):**\n'
#  '   - Raising on this flop with K♦ K♣ could be risky, as it inflates the pot '
#  'and could isolate you against hands that beat you (like sets).\n'
#  '   - Potentially useful against opponents who overvalue top pair or draws '
#  'but risky without more information.\n'
#  '\n'
#  '4. **All-In:**\n'
#  '   - Shoving risks the entire stack with an overpair, likely folding out '
#  'bluffs and weaker hands while being called by better hands.\n'
#  '   - Not typically recommended unless you have a read that the opponent is '
#  'overly aggressive and will call with weaker holdings.\n'
#  '\n'
#  '### Recommended Frequency Strategy:\n'
#  '- **Fold:** 0-5% (only if you have a strong read that the opponent is never '
#  'bluffing and has a very strong range).\n'
#  "- **Call:** 60-70% (default option to keep the opponent's range wide and "
#  'realize your equity).\n'
#  '- **Raise to 43:** 10-15% (if you believe the opponent is capable of '
#  'overvaluing weaker hands or will fold to pressure).\n'
#  '- **Raise to 56:** 5-10% (less frequent due to increased risk and pot '
#  'size).\n'
#  '- **All-In:** 5-10% (only against opponents known for calling with worse '
#  'hands or if you anticipate bluffs).\n'
#  '\n'
#  '### Bet Sizing and Stack Considerations:\n'
#  '- **Pot Size and Stack Depth:** You have approximately 82 big blinds left '
#  'after the pre-flop action. A call keeps the pot manageable and allows for '
#  'more flexible play on the turn and river.\n'
#  '- **Board Texture:** The board is somewhat coordinated with potential '
#  'straight and flush draws, so consider how the turn card might affect the '
#  "hand dynamics and your opponent's range.\n"
#  '\n'
#  'In summary, the most balanced and risk-averse approach with K♦ K♣ on this '
#  'flop would be to call the bet of 19, keeping the opponent’s range wide and '
#  'allowing you to evaluate further action on the turn. Adjust your frequencies '
#  "based on the opponent's tendencies and any additional information you might "
#  'have.')
#
# Output from agent_5:
# ('To analyze this poker scenario, we need to consider several factors, '
#  "including pot odds, equity against the opponent's range, and the strategic "
#  "implications of various actions. Let's break down the situation:\n"
#  '\n'
#  '### Situation Overview:\n'
#  '- **Pre-flop Action:**\n'
#  '  - Under the Gun (UTG) raises to 2.5 big blinds (bb).\n'
#  '  - Cutoff (Hero) with K♦ K♣ raises to 6.5bb.\n'
#  '  - UTG 4-bets to 18bb.\n'
#  '  - Hero calls.\n'
#  '\n'
#  '- **Flop: J♥ 5♠ 6♠**\n'
#  "  - Pot size: 18bb (pre-flop) + 18bb (Hero's call) = 36bb.\n"
#  '  - UTG bets 19bb on the flop.\n'
#  '  - Pot is now 55bb (36bb + 19bb).\n'
#  '\n'
#  '### Mathematical Analysis:\n'
#  '\n'
#  '#### Pot Odds:\n'
#  '- Hero needs to call 19bb into a 55bb pot.\n'
#  '- Pot odds = 19 / (55 + 19) = 19 / 74 ≈ 25.7%.\n'
#  '- Hero needs at least 25.7% equity to call profitably.\n'
#  '\n'
#  '#### Equity Considerations:\n'
#  "- **Hero's Hand:** K♦ K♣\n"
#  '- **Board:** J♥ 5♠ 6♠\n'
#  "- **Opponent's Likely Range:** Given the 4-bet pre-flop, UTG could have "
#  'hands like AA, KK, QQ, JJ, AK, possibly TT, or some bluffs/semi-bluffs like '
#  'A♠K♠, A♠Q♠.\n'
#  '\n'
#  "Using an equity calculator, we can estimate Hero's equity against UTG's "
#  "range. For simplicity, let's assume a range of {AA, KK, QQ, JJ, AKs, AKo, "
#  'A♠Q♠}:\n'
#  '\n'
#  "- **Equity vs. Range:** Hero's equity with K♦ K♣ on this board is roughly "
#  '65-70%, depending on the exact range composition.\n'
#  '\n'
#  '#### Bet Sizing and Frequency Analysis:\n'
#  "Given the pot odds and equity calculation, Hero's hand is strong enough to "
#  "continue. Now, let's consider the possible actions:\n"
#  '\n'
#  '1. **Fold:** \n'
#  "   - Given Hero's equity (~65-70%), folding is not a mathematically sound "
#  'option.\n'
#  '\n'
#  '2. **Call:**\n'
#  '   - Calling keeps the pot manageable and allows Hero to realize equity on '
#  'the turn. Given the favorable equity, calling is a solid option.\n'
#  '\n'
#  '3. **Raise to 43bb or 56bb:**\n'
#  '   - Raising to 43bb or 56bb would apply pressure on UTG and could force '
#  'folds from weaker hands like QQ or AK. However, it risks isolating Hero '
#  'against stronger hands like AA or a set of Jacks.\n'
#  '   - **Raise to 43bb:** This size is less than a pot-sized raise and could '
#  'be used to extract value from draws or weaker overpairs.\n'
#  '   - **Raise to 56bb:** This size is more substantial and could be used to '
#  'build the pot for a potential shove on the turn.\n'
#  "   - Given the strength of Hero's hand, a raise could be considered to "
#  'protect against draws and extract value.\n'
#  '\n'
#  '4. **All-In:**\n'
#  '   - Shoving all-in would maximize fold equity and protect against drawing '
#  'hands. However, it may only be called by hands that have Hero beat or strong '
#  'draws.\n'
#  '   - Shoving can be a high-variance play but could be optimal if Hero '
#  'perceives UTG to be capable of folding strong hands like QQ or AK.\n'
#  '\n'
#  '### Recommended Strategy:\n'
#  '- **Primary Action:** Call (frequency ~60%): This allows Hero to see the '
#  'turn card and make informed decisions based on future actions and board '
#  'developments.\n'
#  '- **Secondary Action:** Raise to 43bb or 56bb (frequency ~30%): This can be '
#  'used to apply pressure, especially if UTG is likely to fold weaker overpairs '
#  'or draws.\n'
#  '- **Occasional Action:** All-In (frequency ~10%): Use this against opponents '
#  'who are likely to fold a significant portion of their range to a shove.\n'
#  '\n'
#  '### Multi-Street Planning:\n'
#  '- **Turn Play:** If Hero calls and the turn is a safe card (non-spade, '
#  'non-Ace), Hero can consider leading out or checking to induce bluffs.\n'
#  "- **River Play:** Plan to make a value bet if Hero's hand remains strong or "
#  "consider bluff catching depending on the opponent's tendencies and the "
#  'runout.\n'
#  '\n'
#  'This analysis balances risk, fold equity, and value extraction, allowing '
#  'Hero to make mathematically sound decisions based on equity and opponent '
#  'tendencies.')
#
# Output from agent_6:
# ("To analyze this scenario effectively, let's break down each component "
#  'step-by-step.\n'
#  '\n'
#  "### Hero's Hand:\n"
#  '- **K♦ K♣** (pocket kings)\n'
#  '\n'
#  '### Board:\n'
#  '- Flop: J♥ 5♠ 6♠\n'
#  '\n'
#  "### Villain's Range (Under the Gun 4-bet):\n"
#  '- Likely strong hands including: Aces (A♠ A♣), Kings (unlikely since we hold '
#  'K♦ K♣), Queens (Q♠ Q♣), Jacks (J♠ J♣), AK (A♠ K♣), and potentially some '
#  'bluffs like A♠ Q♠ or other suited connectors that include spades.\n'
#  '\n'
#  "### Hero's Equity Analysis:\n"
#  "- **Against Villain's Strong Range:**\n"
#  '  - **Pocket Aces (A♠ A♣):** Hero has ~18% equity.\n'
#  '  - **Queens and Lower Pairs:** Hero dominates these hands with ~80% '
#  'equity.\n'
#  '  - **AK (A♠ K♣):** Hero has ~82% equity.\n'
#  '  - **Potential Bluffs (A♠ Q♠, etc.):** Hero holds a significant equity '
#  'advantage unless Villain hits a flush or straight.\n'
#  '\n'
#  '### Board Characteristics:\n'
#  '- **Flush Draw:** Two spades present can provide potential for a flush draw '
#  'with Villain holding spades.\n'
#  '- **Straight Potential:** Limited on this board with current holdings.\n'
#  '\n'
#  '### Decision Analysis:\n'
#  '- **Fold:** Folding is generally suboptimal given the strength of pocket '
#  'kings in this spot unless against very specific reads of Villain only '
#  'holding aces.\n'
#  '  \n'
#  '- **Call:** Allows you to realize equity by seeing the turn and potentially '
#  'the river. This keeps the pot manageable and avoids overcommitting if '
#  'Villain is very strong.\n'
#  '\n'
#  '- **Raise ($43 or $56):** Builds the pot and applies pressure, which could '
#  'force Villain to fold weaker holdings or draws. However, it could isolate '
#  'you against very strong hands that continue.\n'
#  '\n'
#  '- **All-in:** This aggressive move maximizes fold equity but risks running '
#  'into a dominating hand like aces, especially given the pre-flop action.\n'
#  '\n'
#  '### Recommended Play and Frequencies:\n'
#  '- **Call Frequency:** 60% - This allows you to manage the pot size, control '
#  'the hand, and realize your equity on later streets.\n'
#  '  \n'
#  '- **Raise to $43 Frequency:** 20% - This semi-bluff can be used occasionally '
#  'to apply pressure and represent a strong range.\n'
#  '  \n'
#  '- **Raise to $56 Frequency:** 10% - Less frequent than raising to $43, used '
#  'to polarize your range further.\n'
#  '  \n'
#  '- **All-in Frequency:** 5% - Can be employed rarely as a high variance play '
#  'to maximize fold equity against non-nut hands.\n'
#  '  \n'
#  '- **Fold Frequency:** 5% - Reserved for specific reads or meta-game '
#  'considerations where Villain shows extreme strength.\n'
#  '\n'
#  '### Conclusion:\n'
#  'Given the strength of your hand and the potential range of Villain, calling '
#  'is the optimal play most of the time to manage pot size and allow for '
#  'post-flop play. Raising can be mixed in to apply pressure but should be used '
#  'judiciously given the potential for Villain to hold a stronger hand.')

# %%
formatted_input = format_insights_output(parallel_output, input_data)

# %%
formatted_input["insights"]
# Out:
# "Agent 1: In this scenario, we are analyzing a poker hand where Hero, sitting at the cutoff position, holds K♦ K♣. The board comes J♥ 5♠ 6♠ after a series of pre-flop raises, and the Under the Gun (UTG) player has bet 19 on the flop. Let's break down the situation with a focus on Hero's and UTG's ranges, board texture, and strategic considerations:\n\n### Hero's and UTG's Ranges:\n\n**Hero's Range:**\n- **Best-case Holdings:** K♦ K♣ (current hand), A♠ A♦, J♠ J♦, Q♠ Q♦, A♠ K♠ (nut flush draw), A♠ Q♠.\n- **Worst-case Holdings:** Lower pairs (e.g., 9♠ 9♦, 8♠ 8♦), unpaired high cards not suited in spades without strong backdoor potential (e.g., A♦ Q♣).\n\n**UTG's Range:**\n- **Best-case Holdings:** A♠ A♦, J♠ J♦, A♠ K♠, A♠ Q♠ (top pairs, overpairs, nut flush draws).\n- **Potential Bluffs:** A♠ X♠ suited connectors or semi-bluff hands that added aggression pre-flop (e.g., A♠ 10♠, K♠ Q♠).\n\n### Board Texture Analysis:\n- **Texture:** The board of J♥ 5♠ 6♠ is semi-wet. It offers two spades presenting a flush draw and a straight draw potential with low cards.\n- **Impact on Ranges:** The presence of spades means that hands with high spades (A♠, K♠, Q♠) gain equity from flush draw potential. The board connects with mid-range connectors like 7♠ 8♠ or 4♠ 5♠, which may be in the UTG's bluffing range.\n\n### Blockers and Card Removal Effects:\n- **Blockers:** Hero's K♦ K♣ doesn't directly block many of UTG's strongest holdings (like AA or JJ), but it does block potential hands like K♠ Q♠ from being in UTG's range due to the King of clubs.\n- **Implication:** The lack of direct spade blockers in Hero's hand means UTG could hold more flush draw combinations.\n\n### Relevant Draws:\n- **Flush Draws:** Hands like A♠ K♠, K♠ Q♠ are valuable due to the nut flush potential.\n- **Straight Draws:** Although less prevalent, hands like 7♠ 8♠ could be in the mix, especially as bluffs.\n\n### Hero's Strategic Adjustment:\nGiven the board and action, Hero should consider the following:\n\n1. **Folding Frequency:** Low, given the strength of holding KK. However, the presence of overpairs and potential sets in UTG's range should caution against automatic aggression.\n   \n2. **Calling Frequency:** High, as KK is strong on this board, and Hero may want to control the pot size while keeping UTG's range wide enough for future streets.\n\n3. **Raising (43, 56, All-in):** \n   - **Raise to 43:** This play might be used as a semi-bluff or to charge draws, but it risks over-committing against a range that can include AA, sets, or strong draws.\n   - **Raise to 56 or All-in:** These would be overplays unless Hero believes UTG is over-bluffing or would fold hands like QQ, weaker Jx, or draws.\n\n**Overall Strategy:** Hero should lean towards calling, given the strength of KK, while being mindful of turn and river cards that could complete draws. The flop raise can be considered sparingly against an aggressive opponent or one known to over-bluff.\nAgent 2: In this scenario, we need to determine the optimal strategy for the cutoff facing a continuation bet from the under-the-gun (UTG) player after calling a 4-bet pre-flop. We hold K♦ K♣ on a flop of J♥ 5♠ 6♠, and we're considering our action frequencies.\n\n### Analysis:\n\n1. **Pot Size and Stack Depth:**\n   - The pot size after the pre-flop action is 37.5 big blinds (bb).\n   - The UTG bet is for 19 bb into a pot of 37.5 bb, which is a little over half-pot.\n   - Effective stacks are still deep (with more than 80 bb behind after the flop bet), allowing for multiple streets of betting.\n\n2. **Position:**\n   - We are in position (IP) as the cutoff against UTG, which allows us to control the pot size and gain additional information on future streets.\n\n3. **Range Consideration:**\n   - Our pre-flop 3-bet and call of the 4-bet indicates a strong range, including premium pairs (e.g., AA, KK, QQ), AK, and some suited broadways for balance.\n   - The UTG's 4-bet and continuation bet indicate a strong range as well, ty ...

# %%
formatted_input = format_insights_output(parallel_output, input_data)
final_result = agent_chain_7.invoke({
    "input_data": input_data,  # The original input data
    "insights": formatted_input["insights"]  # Just need the formatted insights
})


print(final_result)
# Out:
# ### Unified Action Frequencies and Strategy for Hero's K♦ K♣ on J♥ 5♠ 6♠ Flop
#
# #### 1. **Action Frequencies:**
# - **Call:** 65%
#   - Preserves pot control and allows Hero to realize equity against UTG's range.
#   - Keeps weaker hands and bluffs in Villain's range.
# - **Raise to 43:** 15%
#   - Applies pressure to draws and weaker holdings.
#   - Balances the range by including bluffs and value hands.
# - **Raise to 56:** 10%
#   - Signals strong intent, potentially forcing folds from marginal hands.
#   - Used to polarize Hero's range further.
# - **All-In:** 5%
#   - Maximizes fold equity but should be used sparingly.
#   - Targets scenarios where Villain’s range can fold higher equity hands.
# - **Fold:** 5%
#   - Reserved for specific reads where Villain’s betting pattern suggests a superior range.
#
# #### 2. **Comprehensive Reasoning:**
# - **Range/Board Texture Specialist:** The board J♥ 5♠ 6♠ is semi-wet, with flush and straight draw potential. K♦ K♣ remains strong against UTG’s likely range, which includes high pairs and some bluffs.
# - **GTO Specialist:** Calling most frequently aligns with a balanced approach, maintaining a strong yet concealed range. Occasional raises ensure that Hero's line remains unpredictable.
# - **Exploitative Specialist:** Against players who tend to fold to aggression, occasional raising can exploit their tendencies, forcing folds from weaker hands.
# - **Bluff/Fold Equity Specialist:** Raising to 43 or 56 increases fold equity, especially against hands like QQ or weaker Jx that might not withstand pressure.
# - **Bet Sizing Specialist:** The raise to 43 maximizes pressure without over-committing, while raise to 56 is more polarizing, representing a strong hand or a bluff.
# - **Equity & Combo-Draw Specialist:** Hero’s equity with K♦ K♣ is strong, allowing for a call to realize potential while protecting against draws with strategic raises.
#
# #### 3. **Strategic Considerations:**
# - **Future Streets:** Calling leaves Hero’s range uncapped and maintains flexibility for turn and river decisions. Monitoring turn cards, particularly spades or overcards like an Ace, is crucial.
# - **Adjustments:** Increase raising frequency against opponents who overfold to aggression. Conversely, dial down aggression against players who show strength with 4-bet ranges.
# - **Opponent Response:** Key indicators include reaction to flop raises—quick folds may suggest weakness, while calls or re-raises necessitate caution on future streets.
#
# This strategy offers a balanced approach, integrating insights from all specialists to optimize decision-making given the strength of Hero's hand and the dynamics of the board.
